# %%
import numpy as np
import os
import datetime
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams, colors

import pandas
print(pandas.__version__)

# customized settings
params = {  # 'backend': 'ps',
    'font.family': 'serif',
    'font.serif': 'Latin Modern Roman',
    'font.size': 10,
    'axes.labelsize': 'medium',
    'axes.titlesize': 'medium',
    'legend.fontsize': 'medium',
    'xtick.labelsize': 'small',
    'ytick.labelsize': 'small',
    'savefig.dpi': 150,
    'text.usetex': True}
# tell matplotlib about your params
rcParams.update(params)

# set nice figure sizes
fig_width_pt = 245    # Get this from LaTeX using \showthe\columnwidth
golden_mean = (np.sqrt(5.) - 1.) / 2.  # Aesthetic ratio
ratio = golden_mean
inches_per_pt = 1. / 72.27  # Convert pt to inches
fig_width = fig_width_pt * inches_per_pt  # width in inches
fig_height = fig_width*ratio  # height in inches
fig_size = [2*fig_width, 2*fig_height]
rcParams.update({'figure.figsize': fig_size})
# Out:
# 1.1.5

# %%
def extract_forecasts(data, forecast_period):
    
    dates = []
    dates_pivot = []
    data_quantile_0025_cont = []
    data_quantile_0975_cont = []
    data_point_cont = []
    
    for file in sorted(os.listdir(ensemble_forecast_directory))[7:]:    

        if file[-4:] == '.csv':
            
            print(f"importing{ensemble_forecast_directory+file}")
            data = pd.read_csv(ensemble_forecast_directory+file)
            
            data = data[data['location'] == 'US']
                
            data_quantile = data[data['type'] == 'quantile']
                        
            data_quantile_0025 = data[data['quantile'] == 0.025]    
            data_quantile_0975 = data[data['quantile'] == 0.975]     
            
            data_point = data[data['type'] == 'point']
            
            dates_pivot.append(data_point[data_point['target'] == forecast_period]['forecast_date'].to_numpy()[0])
            
            dates.append(data_quantile_0025[data_quantile_0025['target'] == forecast_period]['target_end_date'].to_numpy()[0])
            data_quantile_0025_cont.append(float(data_quantile_0025[data_quantile_0025['target'] == forecast_period]['value']))
            data_quantile_0975_cont.append(float(data_quantile_0975[data_quantile_0975['target'] == forecast_period]['value']))
            data_point_cont.append(float(data_point[data_point['target'] == forecast_period]['value']))
    
    dates = [datetime.datetime.strptime(date, '%Y-%m-%d') for date in dates]
    dates_pivot = [datetime.datetime.strptime(date, '%Y-%m-%d') for date in dates_pivot]
    
    return np.asarray(dates), np.asarray(dates_pivot), np.asarray(data_quantile_0025_cont), np.asarray(data_quantile_0975_cont), np.asarray(data_point_cont)

# %%
covid_data = pd.read_csv('../../data/Covid19_ground_truth_reports/fetched_Dec_2021/time_series_covid19_deaths_US.csv')

print(covid_data.head())
colnames = covid_data.columns.tolist()
# Out:
#         UID iso2 iso3  code3    FIPS   Admin2 Province_State Country_Region  \
# 0  84001001   US  USA    840  1001.0  Autauga        Alabama             US
# 1  84001003   US  USA    840  1003.0  Baldwin        Alabama             US
# 2  84001005   US  USA    840  1005.0  Barbour        Alabama             US
# 3  84001007   US  USA    840  1007.0     Bibb        Alabama             US
# 4  84001009   US  USA    840  1009.0   Blount        Alabama             US
#
#          Lat      Long_  ... 12/19/21  12/20/21  12/21/21  12/22/21  12/23/21  \
# 0  32.539527 -86.644082  ...      159       159       160       160       160
# 1  30.727750 -87.722071  ...      592       592       592       593       593
# 2  31.868263 -85.387129  ...       81        81        81        81        81
# 3  32.996421 -87.125115  ...       95        95        95        95        95
# 4  33.982109 -86.567906  ...      195       195       197       197       197
#
#    12/24/21  12/25/21  12/26/21  12/27/21  12/28/21
# 0       160       160       160       160       160
# 1       593       593       593       593       593
# 2        81        81        81        81        81
# 3        95        95        95        95        95
# 4       197       197       197       197       197
#
# [5 rows x 719 columns]

# %%
start = datetime.datetime.strptime(colnames[12], "%m/%d/%y")
end = datetime.datetime.strptime(colnames[-1], "%m/%d/%y")

print(start, end)

dates_covid_data = np.asarray([start + datetime.timedelta(days=x) for x in range(0, (end-start).days)])
dates_covid_data = dates_covid_data[3:][::7]

deaths_covid_data = [covid_data.iloc[:,i].sum() for i in range(12,len(colnames))]
deaths_covid_data_dates = [colnames[i] for i in range(12,len(colnames))]

original_cum_signal = deaths_covid_data[3:]
deaths_covid_data = np.diff(deaths_covid_data[3:])
plt.plot(deaths_covid_data,'r')

original_signal = deaths_covid_data
original_signal_dates = deaths_covid_data_dates[4:]
# Out:
# 2020-01-22 00:00:00 2021-12-28 00:00:00

# %%
ensemble_forecast_directory = '../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/'

dates_1wk, dates_forecast_1wk, data_quantile_0025_1wk, data_quantile_0975_1wk, data_point_1wk = \
extract_forecasts(ensemble_forecast_directory, '1 wk ahead inc death')

dates_2wk, dates_forecast_2wk, data_quantile_0025_2wk, data_quantile_0975_2wk, data_point_2wk = \
extract_forecasts(ensemble_forecast_directory, '2 wk ahead inc death')

dates_3wk, dates_forecast_3wk, data_quantile_0025_3wk, data_quantile_0975_3wk, data_point_3wk = \
extract_forecasts(ensemble_forecast_directory, '3 wk ahead inc death')

dates_4wk, dates_forecast_4wk, data_quantile_0025_4wk, data_quantile_0975_4wk, data_point_4wk = \
extract_forecasts(ensemble_forecast_directory, '4 wk ahead inc death')
# Out:
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-08-03-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-08-10-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-08-17-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-08-24-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-08-31-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-09-07-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-09-14-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-09-21-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-09-28-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-10-05-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-10-12-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-10-19-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-10-26-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-11-02-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-11-09-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-11-16-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-11-23-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-11-30-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-12-07-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-12-14-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-12-21-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-12-28-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-01-04-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-01-11-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-01-18-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-01-25-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-02-01-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-02-08-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-02-15-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-02-22-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-03-01-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-03-08-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-03-15-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-03-22-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-03-29-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-04-05-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-04-12-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-04-19-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-04-26-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-05-03-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-05-10-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-05-17-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-05-24-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-05-31-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-06-07-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-06-14-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-06-21-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-06-28-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-07-05-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-07-12-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-07-19-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-07-26-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-08-02-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-08-09-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-08-16-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-08-23-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-08-30-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-09-06-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-09-13-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-09-20-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-09-27-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-10-04-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-10-11-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-10-18-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-10-25-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-11-08-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-11-15-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-11-22-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-11-29-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-12-06-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-12-13-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-12-20-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-12-27-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-08-03-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-08-10-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-08-17-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-08-24-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-08-31-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-09-07-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-09-14-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-09-21-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-09-28-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-10-05-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-10-12-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-10-19-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-10-26-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-11-02-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-11-09-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-11-16-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-11-23-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-11-30-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-12-07-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-12-14-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-12-21-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-12-28-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-01-04-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-01-11-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-01-18-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-01-25-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-02-01-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-02-08-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-02-15-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-02-22-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-03-01-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-03-08-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-03-15-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-03-22-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-03-29-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-04-05-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-04-12-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-04-19-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-04-26-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-05-03-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-05-10-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-05-17-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-05-24-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-05-31-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-06-07-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-06-14-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-06-21-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-06-28-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-07-05-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-07-12-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-07-19-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-07-26-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-08-02-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-08-09-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-08-16-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-08-23-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-08-30-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-09-06-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-09-13-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-09-20-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-09-27-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-10-04-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-10-11-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-10-18-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-10-25-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-11-08-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-11-15-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-11-22-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-11-29-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-12-06-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-12-13-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-12-20-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-12-27-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-08-03-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-08-10-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-08-17-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-08-24-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-08-31-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-09-07-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-09-14-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-09-21-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-09-28-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-10-05-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-10-12-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-10-19-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-10-26-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-11-02-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-11-09-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-11-16-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-11-23-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-11-30-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-12-07-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-12-14-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-12-21-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-12-28-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-01-04-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-01-11-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-01-18-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-01-25-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-02-01-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-02-08-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-02-15-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-02-22-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-03-01-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-03-08-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-03-15-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-03-22-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-03-29-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-04-05-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-04-12-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-04-19-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-04-26-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-05-03-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-05-10-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-05-17-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-05-24-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-05-31-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-06-07-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-06-14-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-06-21-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-06-28-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-07-05-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-07-12-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-07-19-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-07-26-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-08-02-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-08-09-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-08-16-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-08-23-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-08-30-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-09-06-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-09-13-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-09-20-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-09-27-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-10-04-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-10-11-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-10-18-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-10-25-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-11-08-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-11-15-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-11-22-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-11-29-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-12-06-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-12-13-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-12-20-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-12-27-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-08-03-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-08-10-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-08-17-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-08-24-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-08-31-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-09-07-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-09-14-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-09-21-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-09-28-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-10-05-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-10-12-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-10-19-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-10-26-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-11-02-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-11-09-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-11-16-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-11-23-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-11-30-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-12-07-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-12-14-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-12-21-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2020-12-28-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-01-04-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-01-11-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-01-18-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-01-25-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-02-01-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-02-08-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-02-15-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-02-22-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-03-01-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-03-08-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-03-15-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-03-22-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-03-29-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-04-05-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-04-12-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-04-19-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-04-26-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-05-03-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-05-10-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-05-17-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-05-24-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-05-31-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-06-07-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-06-14-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-06-21-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-06-28-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-07-05-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-07-12-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-07-19-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-07-26-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-08-02-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-08-09-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-08-16-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-08-23-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-08-30-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-09-06-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-09-13-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-09-20-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-09-27-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-10-04-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-10-11-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-10-18-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-10-25-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-11-08-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-11-15-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-11-22-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-11-29-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-12-06-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-12-13-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-12-20-epiforecasts-ensemble1.csv
# importing../../data/CDC_ensemble_forecasts/fetched_Dec_2021/COVIDhub-ensemble/2021-12-27-epiforecasts-ensemble1.csv

# %%
for i in range(0,len(dates_4wk)):
    print(f"target:{dates_4wk[i]}|forecast:{dates_forecast_4wk[i]}|value:{data_point_4wk[i]}|data_quantile_0025_4wk:{data_quantile_0025_4wk[i]}")
# Out:
# target:2020-08-29 00:00:00|forecast:2020-08-03 00:00:00|value:9334.0|data_quantile_0025_4wk:4703.0
# target:2020-09-05 00:00:00|forecast:2020-08-10 00:00:00|value:8575.0|data_quantile_0025_4wk:2249.0
# target:2020-09-12 00:00:00|forecast:2020-08-17 00:00:00|value:7707.0|data_quantile_0025_4wk:4889.0
# target:2020-09-19 00:00:00|forecast:2020-08-24 00:00:00|value:5985.0|data_quantile_0025_4wk:2761.0
# target:2020-09-26 00:00:00|forecast:2020-08-31 00:00:00|value:4872.0|data_quantile_0025_4wk:804.0
# target:2020-10-03 00:00:00|forecast:2020-09-07 00:00:00|value:4604.0|data_quantile_0025_4wk:818.0
# target:2020-10-10 00:00:00|forecast:2020-09-14 00:00:00|value:3273.0|data_quantile_0025_4wk:1237.0
# target:2020-10-17 00:00:00|forecast:2020-09-21 00:00:00|value:3385.0|data_quantile_0025_4wk:1644.0
# target:2020-10-24 00:00:00|forecast:2020-09-28 00:00:00|value:4374.0|data_quantile_0025_4wk:2673.0
# target:2020-10-31 00:00:00|forecast:2020-10-05 00:00:00|value:4309.0|data_quantile_0025_4wk:2888.0
# target:2020-11-07 00:00:00|forecast:2020-10-12 00:00:00|value:4976.0|data_quantile_0025_4wk:3627.0
# target:2020-11-14 00:00:00|forecast:2020-10-19 00:00:00|value:5004.0|data_quantile_0025_4wk:3078.0
# target:2020-11-21 00:00:00|forecast:2020-10-26 00:00:00|value:5457.0|data_quantile_0025_4wk:2600.0
# target:2020-11-28 00:00:00|forecast:2020-11-02 00:00:00|value:7442.0|data_quantile_0025_4wk:954.0
# target:2020-12-05 00:00:00|forecast:2020-11-09 00:00:00|value:8534.0|data_quantile_0025_4wk:1963.0
# target:2020-12-12 00:00:00|forecast:2020-11-16 00:00:00|value:11175.0|data_quantile_0025_4wk:5194.0
# target:2020-12-19 00:00:00|forecast:2020-11-23 00:00:00|value:34665.0|data_quantile_0025_4wk:19580.0
# target:2020-12-26 00:00:00|forecast:2020-11-30 00:00:00|value:10339.0|data_quantile_0025_4wk:5195.0
# target:2021-01-02 00:00:00|forecast:2020-12-07 00:00:00|value:26562.0|data_quantile_0025_4wk:14402.0
# target:2021-01-09 00:00:00|forecast:2020-12-14 00:00:00|value:20484.138|data_quantile_0025_4wk:14056.8591
# target:2021-01-16 00:00:00|forecast:2020-12-21 00:00:00|value:18243.181|data_quantile_0025_4wk:10975.51525
# target:2021-01-23 00:00:00|forecast:2020-12-28 00:00:00|value:12890.9715|data_quantile_0025_4wk:4167.009875
# target:2021-01-30 00:00:00|forecast:2021-01-04 00:00:00|value:19577.663|data_quantile_0025_4wk:9953.402125
# target:2021-02-06 00:00:00|forecast:2021-01-11 00:00:00|value:23329.0|data_quantile_0025_4wk:13852.0
# target:2021-02-13 00:00:00|forecast:2021-01-18 00:00:00|value:23467.0|data_quantile_0025_4wk:11071.0
# target:2021-02-20 00:00:00|forecast:2021-01-25 00:00:00|value:16604.0|data_quantile_0025_4wk:5819.0
# target:2021-02-27 00:00:00|forecast:2021-02-01 00:00:00|value:15504.0|data_quantile_0025_4wk:7711.0
# target:2021-03-06 00:00:00|forecast:2021-02-08 00:00:00|value:16764.0|data_quantile_0025_4wk:6086.0
# target:2021-03-13 00:00:00|forecast:2021-02-15 00:00:00|value:25202.0|data_quantile_0025_4wk:10293.0
# target:2021-03-20 00:00:00|forecast:2021-02-22 00:00:00|value:6453.0|data_quantile_0025_4wk:4147.0
# target:2021-03-27 00:00:00|forecast:2021-03-01 00:00:00|value:7413.0|data_quantile_0025_4wk:4754.0
# target:2021-04-03 00:00:00|forecast:2021-03-08 00:00:00|value:8275.0|data_quantile_0025_4wk:3709.0
# target:2021-04-10 00:00:00|forecast:2021-03-15 00:00:00|value:5906.0|data_quantile_0025_4wk:3427.0
# target:2021-04-17 00:00:00|forecast:2021-03-22 00:00:00|value:6700.0|data_quantile_0025_4wk:2504.0
# target:2021-04-24 00:00:00|forecast:2021-03-29 00:00:00|value:8340.0|data_quantile_0025_4wk:3513.0
# target:2021-05-01 00:00:00|forecast:2021-04-05 00:00:00|value:3947.0|data_quantile_0025_4wk:783.55
# target:2021-05-08 00:00:00|forecast:2021-04-12 00:00:00|value:8631.0|data_quantile_0025_4wk:5692.0
# target:2021-05-15 00:00:00|forecast:2021-04-19 00:00:00|value:4926.166666666671|data_quantile_0025_4wk:3162.65
# target:2021-05-22 00:00:00|forecast:2021-04-26 00:00:00|value:3397.0|data_quantile_0025_4wk:1873.0
# target:2021-05-29 00:00:00|forecast:2021-05-03 00:00:00|value:4476.0|data_quantile_0025_4wk:2684.0
# target:2021-06-05 00:00:00|forecast:2021-05-10 00:00:00|value:4989.0|data_quantile_0025_4wk:2063.0
# target:2021-06-12 00:00:00|forecast:2021-05-17 00:00:00|value:1953.0|data_quantile_0025_4wk:1386.0
# target:2021-06-19 00:00:00|forecast:2021-05-24 00:00:00|value:1455.0|data_quantile_0025_4wk:1005.0
# target:2021-06-26 00:00:00|forecast:2021-05-31 00:00:00|value:3564.0|data_quantile_0025_4wk:2707.0
# target:2021-07-03 00:00:00|forecast:2021-06-07 00:00:00|value:1105.0|data_quantile_0025_4wk:646.0
# target:2021-07-10 00:00:00|forecast:2021-06-14 00:00:00|value:1860.0|data_quantile_0025_4wk:1078.0
# target:2021-07-17 00:00:00|forecast:2021-06-21 00:00:00|value:1188.0|data_quantile_0025_4wk:699.0
# target:2021-07-24 00:00:00|forecast:2021-06-28 00:00:00|value:1496.0|data_quantile_0025_4wk:865.0
# target:2021-07-31 00:00:00|forecast:2021-07-05 00:00:00|value:1709.0|data_quantile_0025_4wk:1014.0
# target:2021-08-07 00:00:00|forecast:2021-07-12 00:00:00|value:3231.0|data_quantile_0025_4wk:1886.7
# target:2021-08-14 00:00:00|forecast:2021-07-19 00:00:00|value:1970.0|data_quantile_0025_4wk:1207.85
# target:2021-08-21 00:00:00|forecast:2021-07-26 00:00:00|value:2525.0|data_quantile_0025_4wk:1318.975
# target:2021-08-28 00:00:00|forecast:2021-08-02 00:00:00|value:7877.0|data_quantile_0025_4wk:4479.0
# target:2021-09-04 00:00:00|forecast:2021-08-09 00:00:00|value:6607.0|data_quantile_0025_4wk:3510.0
# target:2021-09-11 00:00:00|forecast:2021-08-16 00:00:00|value:7619.0|data_quantile_0025_4wk:4419.0
# target:2021-09-18 00:00:00|forecast:2021-08-23 00:00:00|value:13835.0|data_quantile_0025_4wk:6079.0
# target:2021-09-25 00:00:00|forecast:2021-08-30 00:00:00|value:14316.0|data_quantile_0025_4wk:7022.0
# target:2021-10-02 00:00:00|forecast:2021-09-06 00:00:00|value:13904.0|data_quantile_0025_4wk:8648.0
# target:2021-10-09 00:00:00|forecast:2021-09-13 00:00:00|value:13990.0|data_quantile_0025_4wk:7350.0
# target:2021-10-16 00:00:00|forecast:2021-09-20 00:00:00|value:14629.0|data_quantile_0025_4wk:8702.0
# target:2021-10-23 00:00:00|forecast:2021-09-27 00:00:00|value:9420.0|data_quantile_0025_4wk:2435.0
# target:2021-10-30 00:00:00|forecast:2021-10-04 00:00:00|value:9530.0|data_quantile_0025_4wk:4549.0
# target:2021-11-06 00:00:00|forecast:2021-10-11 00:00:00|value:7099.0|data_quantile_0025_4wk:3662.0
# target:2021-11-13 00:00:00|forecast:2021-10-18 00:00:00|value:7385.0|data_quantile_0025_4wk:4233.0
# target:2021-11-20 00:00:00|forecast:2021-10-25 00:00:00|value:6877.0|data_quantile_0025_4wk:3751.0
# target:2021-12-04 00:00:00|forecast:2021-11-08 00:00:00|value:7848.0|data_quantile_0025_4wk:5014.0
# target:2021-12-11 00:00:00|forecast:2021-11-15 00:00:00|value:12687.0|data_quantile_0025_4wk:7455.0
# target:2021-12-18 00:00:00|forecast:2021-11-22 00:00:00|value:11930.0|data_quantile_0025_4wk:7822.0
# target:2021-12-25 00:00:00|forecast:2021-11-29 00:00:00|value:4735.0|data_quantile_0025_4wk:1481.0
# target:2022-01-01 00:00:00|forecast:2021-12-06 00:00:00|value:16344.0|data_quantile_0025_4wk:7092.0
# target:2022-01-08 00:00:00|forecast:2021-12-13 00:00:00|value:11789.0|data_quantile_0025_4wk:5554.0
# target:2022-01-15 00:00:00|forecast:2021-12-20 00:00:00|value:9871.0|data_quantile_0025_4wk:5112.0
# target:2022-01-22 00:00:00|forecast:2021-12-27 00:00:00|value:10231.0|data_quantile_0025_4wk:6204.0

# %%
def euler_lagrange(signal_cum_df__, weeks__ = 1, diff_length__ = 7):
    assert signal_cum_df__[-1]>signal_cum_df__[-2] # monotone increasing check
    
    print("euler-lagrange method input:", signal_cum_df__.tail())
    
    # get discrete derivative [diff_length__] of signal_cum_df_ -- cumulative numbers -- less noisy)
    derivative_week_discrete = signal_cum_df__[-1] - signal_cum_df__[-diff_length__]  
    print(f"euler-lagrange derivative{signal_cum_df__[-1]}-{signal_cum_df__[-diff_length__]}=", derivative_week_discrete)
    
    # total variation optimization to denoise 2nd derivative 
    xinv = extract_min_total_variation_optimization(signal_cum_df__.to_numpy())
    
    
    # 2nd derivative after total variation optimization 
    derivative__2nd_weekly = (xinv[-1] - xinv[-diff_length__])
    print("euler-lagrange 2nd derivative:", derivative__2nd_weekly)
            
    derivative_corr =  weeks__*derivative__2nd_weekly
    print("number of weeks to future and correction", weeks__, derivative_corr)
    euler_lagrange_pred = derivative_week_discrete + derivative_corr
    
    return euler_lagrange_pred


import pylops
def extract_min_total_variation_optimization(original_signal__):
    y = np.diff(original_signal__)
    nx = len(y)
    Iop = pylops.Identity(nx)
    
    # Model: y = Iop*(x + n), n - noise, 
    # xinv = argmin ||y-Ix||_2 + lambda*||\grad[x]||_2
    
    D2op = pylops.SecondDerivative(nx, edge=True)
    lamda = 1e5
    xinv = pylops.optimization.leastsquares.RegularizedInversion(Iop, [D2op], y,
                                                          epsRs=[np.sqrt(lamda/2)],
                                                          **dict(iter_lim=30))
    
    return xinv

# %%
def error_comparison_all_raw(covid_data_raw__, cdc_ensemble_forecast__, cdc_dates__, weeks__):
    # total variation on derivative + reconstruction minimization ~ Euler-Lagrange 
    div = 1
    error_euler = []
    error_ensemble = []
    error_date = []
    euler_pred_list = []
    cdc_pred_list = []
    pivot_date = []
    ground_truth_list = []
    for i in range(len(cdc_dates__)):
        date_tmp = cdc_dates__[i]
        print("<<<prediction date", date_tmp.strftime("%-m/%-d/%y"))
        ind = np.where(covid_data_raw__.columns == date_tmp.strftime("%-m/%-d/%y"))
        if len(ind[0]):
            error_date.append(date_tmp)
            ind = ind[0][0]
            
            print("ind element on covid data",ind,  covid_data.iloc[:,ind].sum())
            
            current_week_slice = covid_data.iloc[:,ind-7+1:ind+1].sum()
            print("current week (prediction week)", current_week_slice)
            
            current_week_death_diff = current_week_slice[-1]-current_week_slice[0]
            print("current week dead diff", current_week_death_diff)
 
            all_history_slice = covid_data.iloc[:,12:ind-7*weeks__+1+1].sum()
            print("historical slice",all_history_slice.tail(14))
            print("last date history", all_history_slice.index[-1])
            pivot_date.append( datetime.datetime.strptime(all_history_slice.index[-1], "%m/%d/%y") )
        
            euler_pred = euler_lagrange(all_history_slice, weeks__)
            euler_pred_list.append(euler_pred)
            print("euler pred with dedicated function", euler_pred)
            
            error_euler.append(abs(euler_pred-current_week_death_diff))
            error_ensemble.append(abs(cdc_ensemble_forecast__[i]-current_week_death_diff))
            cdc_pred_list.append(cdc_ensemble_forecast__[i])
            ground_truth_list.append(current_week_death_diff)
            
            print(f"cdc estimate {cdc_ensemble_forecast__[i]} for {cdc_dates__[i]} or {date_tmp} >>>")
      
    error_euler = np.transpose(np.asarray(error_euler)/div)
    error_ensemble =  np.transpose(np.asarray(error_ensemble)/div )
    error_euler_cum =  np.transpose(np.cumsum(error_euler))
    error_ensemble_cum =  np.transpose(np.cumsum(error_ensemble))
    error_date =  np.transpose(np.asarray(error_date))
    euler_pred_list = np.transpose(np.asarray(euler_pred_list))
    cdc_pred_list = np.transpose(np.asarray(cdc_pred_list))
    ground_truth = np.transpose(np.asarray(ground_truth_list))
    
    print(error_euler.shape)
    
    data = [error_euler, error_ensemble, error_euler_cum, error_ensemble_cum, error_date,pivot_date,\
            euler_pred_list, cdc_pred_list, ground_truth]
    df = pd.DataFrame(data).T
    
    df.columns = ["error_euler","error_cdc_ensemble","cum_error_euler",\
                                       "cum_error_cdc_ensemble","target_prediction_date", "prediction_made_date",\
                 "euler_prediction_value", "cdc_prediction_value", "ground_truth_incidence"]
    
    return df
    #return error_euler, error_ensemble, error_euler_cum, error_ensemble_cum, error_date

# %%
path_results = "results/Jan_2022/"

# %%
week_forecast = 1

if (week_forecast == 1):
    df = error_comparison_all_raw(covid_data, data_point_1wk, dates_1wk, week_forecast)
elif (week_forecast == 2):
    df = error_comparison_all_raw(covid_data, data_point_2wk, dates_2wk, week_forecast)
elif (week_forecast == 3):
    df = error_comparison_all_raw(covid_data, data_point_3wk, dates_3wk, week_forecast)
elif (week_forecast == 4):
    df = error_comparison_all_raw(covid_data, data_point_4wk, dates_4wk, week_forecast)
# Out:
# <<<prediction date 8/8/20
# ind element on covid data 211 162185
# current week (prediction week) 8/2/20    155404
# 8/3/20    155963
# 8/4/20    157218
# 8/5/20    158626
# 8/6/20    159807
# 8/7/20    161098
# 8/8/20    162185
# dtype: int64
# current week dead diff 6781
# historical slice 7/20/20    141590
# 7/21/20    142686
# 7/22/20    143911
# 7/23/20    144997
# 7/24/20    146091
# 7/25/20    147060
# 7/26/20    147594
# 7/27/20    148694
# 7/28/20    149916
# 7/29/20    151356
# 7/30/20    152645
# 7/31/20    153828
# 8/1/20     154947
# 8/2/20     155404
# dtype: int64
# last date history 8/2/20
# euler-lagrange method input: 7/29/20    151356
# 7/30/20    152645
# 7/31/20    153828
# 8/1/20     154947
# 8/2/20     155404
# dtype: int64
# euler-lagrange derivative155404-148694= 6710
# euler-lagrange 2nd derivative: -53.83289921484908
# number of weeks to future and correction 1 -53.83289921484908
# euler pred with dedicated function 6656.167100785151
# cdc estimate 7794.0 for 2020-08-08 00:00:00 or 2020-08-08 00:00:00 >>>
# <<<prediction date 8/15/20
# ind element on covid data 218 169278
# current week (prediction week) 8/9/20     162757
# 8/10/20    163274
# 8/11/20    164371
# 8/12/20    165886
# 8/13/20    166924
# 8/14/20    168233
# 8/15/20    169278
# dtype: int64
# current week dead diff 6521
# historical slice 7/27/20    148694
# 7/28/20    149916
# 7/29/20    151356
# 7/30/20    152645
# 7/31/20    153828
# 8/1/20     154947
# 8/2/20     155404
# 8/3/20     155963
# 8/4/20     157218
# 8/5/20     158626
# 8/6/20     159807
# 8/7/20     161098
# 8/8/20     162185
# 8/9/20     162757
# dtype: int64
# last date history 8/9/20
# euler-lagrange method input: 8/5/20    158626
# 8/6/20    159807
# 8/7/20    161098
# 8/8/20    162185
# 8/9/20    162757
# dtype: int64
# euler-lagrange derivative162757-155963= 6794
# euler-lagrange 2nd derivative: -36.82715285795075
# number of weeks to future and correction 1 -36.82715285795075
# euler pred with dedicated function 6757.172847142049
# cdc estimate 7619.0 for 2020-08-15 00:00:00 or 2020-08-15 00:00:00 >>>
# <<<prediction date 8/22/20
# ind element on covid data 225 176052
# current week (prediction week) 8/16/20    169886
# 8/17/20    170355
# 8/18/20    171578
# 8/19/20    172865
# 8/20/20    173972
# 8/21/20    175073
# 8/22/20    176052
# dtype: int64
# current week dead diff 6166
# historical slice 8/3/20     155963
# 8/4/20     157218
# 8/5/20     158626
# 8/6/20     159807
# 8/7/20     161098
# 8/8/20     162185
# 8/9/20     162757
# 8/10/20    163274
# 8/11/20    164371
# 8/12/20    165886
# 8/13/20    166924
# 8/14/20    168233
# 8/15/20    169278
# 8/16/20    169886
# dtype: int64
# last date history 8/16/20
# euler-lagrange method input: 8/12/20    165886
# 8/13/20    166924
# 8/14/20    168233
# 8/15/20    169278
# 8/16/20    169886
# dtype: int64
# euler-lagrange derivative169886-163274= 6612
# euler-lagrange 2nd derivative: -28.736900504269215
# number of weeks to future and correction 1 -28.736900504269215
# euler pred with dedicated function 6583.263099495731
# cdc estimate 7345.0 for 2020-08-22 00:00:00 or 2020-08-22 00:00:00 >>>
# <<<prediction date 8/29/20
# ind element on covid data 232 182440
# current week (prediction week) 8/23/20    176547
# 8/24/20    176989
# 8/25/20    178223
# 8/26/20    179401
# 8/27/20    180516
# 8/28/20    181457
# 8/29/20    182440
# dtype: int64
# current week dead diff 5893
# historical slice 8/10/20    163274
# 8/11/20    164371
# 8/12/20    165886
# 8/13/20    166924
# 8/14/20    168233
# 8/15/20    169278
# 8/16/20    169886
# 8/17/20    170355
# 8/18/20    171578
# 8/19/20    172865
# 8/20/20    173972
# 8/21/20    175073
# 8/22/20    176052
# 8/23/20    176547
# dtype: int64
# last date history 8/23/20
# euler-lagrange method input: 8/19/20    172865
# 8/20/20    173972
# 8/21/20    175073
# 8/22/20    176052
# 8/23/20    176547
# dtype: int64
# euler-lagrange derivative176547-170355= 6192
# euler-lagrange 2nd derivative: -65.07034265530876
# number of weeks to future and correction 1 -65.07034265530876
# euler pred with dedicated function 6126.929657344691
# cdc estimate 6108.0 for 2020-08-29 00:00:00 or 2020-08-29 00:00:00 >>>
# <<<prediction date 9/5/20
# ind element on covid data 239 188326
# current week (prediction week) 8/30/20    182889
# 8/31/20    183383
# 9/1/20     184444
# 9/2/20     185496
# 9/3/20     186527
# 9/4/20     187506
# 9/5/20     188326
# dtype: int64
# current week dead diff 5437
# historical slice 8/17/20    170355
# 8/18/20    171578
# 8/19/20    172865
# 8/20/20    173972
# 8/21/20    175073
# 8/22/20    176052
# 8/23/20    176547
# 8/24/20    176989
# 8/25/20    178223
# 8/26/20    179401
# 8/27/20    180516
# 8/28/20    181457
# 8/29/20    182440
# 8/30/20    182889
# dtype: int64
# last date history 8/30/20
# euler-lagrange method input: 8/26/20    179401
# 8/27/20    180516
# 8/28/20    181457
# 8/29/20    182440
# 8/30/20    182889
# dtype: int64
# euler-lagrange derivative182889-176989= 5900
# euler-lagrange 2nd derivative: -54.54924443724531
# number of weeks to future and correction 1 -54.54924443724531
# euler pred with dedicated function 5845.450755562755
# cdc estimate 5940.0 for 2020-09-05 00:00:00 or 2020-09-05 00:00:00 >>>
# <<<prediction date 9/12/20
# ind element on covid data 246 193488
# current week (prediction week) 9/6/20     188766
# 9/7/20     189086
# 9/8/20     189554
# 9/9/20     190659
# 9/10/20    191583
# 9/11/20    192739
# 9/12/20    193488
# dtype: int64
# current week dead diff 4722
# historical slice 8/24/20    176989
# 8/25/20    178223
# 8/26/20    179401
# 8/27/20    180516
# 8/28/20    181457
# 8/29/20    182440
# 8/30/20    182889
# 8/31/20    183383
# 9/1/20     184444
# 9/2/20     185496
# 9/3/20     186527
# 9/4/20     187506
# 9/5/20     188326
# 9/6/20     188766
# dtype: int64
# last date history 9/6/20
# euler-lagrange method input: 9/2/20    185496
# 9/3/20    186527
# 9/4/20    187506
# 9/5/20    188326
# 9/6/20    188766
# dtype: int64
# euler-lagrange derivative188766-183383= 5383
# euler-lagrange 2nd derivative: -59.42008214012509
# number of weeks to future and correction 1 -59.42008214012509
# euler pred with dedicated function 5323.5799178598745
# cdc estimate 5461.0 for 2020-09-12 00:00:00 or 2020-09-12 00:00:00 >>>
# <<<prediction date 9/19/20
# ind element on covid data 253 199005
# current week (prediction week) 9/13/20    193888
# 9/14/20    194311
# 9/15/20    195513
# 9/16/20    196468
# 9/17/20    197334
# 9/18/20    198294
# 9/19/20    199005
# dtype: int64
# current week dead diff 5117
# historical slice 8/31/20    183383
# 9/1/20     184444
# 9/2/20     185496
# 9/3/20     186527
# 9/4/20     187506
# 9/5/20     188326
# 9/6/20     188766
# 9/7/20     189086
# 9/8/20     189554
# 9/9/20     190659
# 9/10/20    191583
# 9/11/20    192739
# 9/12/20    193488
# 9/13/20    193888
# dtype: int64
# last date history 9/13/20
# euler-lagrange method input: 9/9/20     190659
# 9/10/20    191583
# 9/11/20    192739
# 9/12/20    193488
# 9/13/20    193888
# dtype: int64
# euler-lagrange derivative193888-189086= 4802
# euler-lagrange 2nd derivative: -8.214062214902015
# number of weeks to future and correction 1 -8.214062214902015
# euler pred with dedicated function 4793.785937785098
# cdc estimate 4477.0 for 2020-09-19 00:00:00 or 2020-09-19 00:00:00 >>>
# <<<prediction date 9/26/20
# ind element on covid data 260 204393
# current week (prediction week) 9/20/20    199275
# 9/21/20    199688
# 9/22/20    200723
# 9/23/20    201788
# 9/24/20    202695
# 9/25/20    203610
# 9/26/20    204393
# dtype: int64
# current week dead diff 5118
# historical slice 9/7/20     189086
# 9/8/20     189554
# 9/9/20     190659
# 9/10/20    191583
# 9/11/20    192739
# 9/12/20    193488
# 9/13/20    193888
# 9/14/20    194311
# 9/15/20    195513
# 9/16/20    196468
# 9/17/20    197334
# 9/18/20    198294
# 9/19/20    199005
# 9/20/20    199275
# dtype: int64
# last date history 9/20/20
# euler-lagrange method input: 9/16/20    196468
# 9/17/20    197334
# 9/18/20    198294
# 9/19/20    199005
# 9/20/20    199275
# dtype: int64
# euler-lagrange derivative199275-194311= 4964
# euler-lagrange 2nd derivative: -71.59792203104644
# number of weeks to future and correction 1 -71.59792203104644
# euler pred with dedicated function 4892.402077968954
# cdc estimate 4470.0 for 2020-09-26 00:00:00 or 2020-09-26 00:00:00 >>>
# <<<prediction date 10/3/20
# ind element on covid data 267 209323
# current week (prediction week) 9/27/20    204705
# 9/28/20    205046
# 9/29/20    205948
# 9/30/20    206880
# 10/1/20    207796
# 10/2/20    208637
# 10/3/20    209323
# dtype: int64
# current week dead diff 4618
# historical slice 9/14/20    194311
# 9/15/20    195513
# 9/16/20    196468
# 9/17/20    197334
# 9/18/20    198294
# 9/19/20    199005
# 9/20/20    199275
# 9/21/20    199688
# 9/22/20    200723
# 9/23/20    201788
# 9/24/20    202695
# 9/25/20    203610
# 9/26/20    204393
# 9/27/20    204705
# dtype: int64
# last date history 9/27/20
# euler-lagrange method input: 9/23/20    201788
# 9/24/20    202695
# 9/25/20    203610
# 9/26/20    204393
# 9/27/20    204705
# dtype: int64
# euler-lagrange derivative204705-199688= 5017
# euler-lagrange 2nd derivative: -39.97894449478332
# number of weeks to future and correction 1 -39.97894449478332
# euler pred with dedicated function 4977.021055505216
# cdc estimate 4694.0 for 2020-10-03 00:00:00 or 2020-10-03 00:00:00 >>>
# <<<prediction date 10/10/20
# ind element on covid data 274 214409
# current week (prediction week) 10/4/20     209692
# 10/5/20     210174
# 10/6/20     210875
# 10/7/20     211794
# 10/8/20     212776
# 10/9/20     213749
# 10/10/20    214409
# dtype: int64
# current week dead diff 4717
# historical slice 9/21/20    199688
# 9/22/20    200723
# 9/23/20    201788
# 9/24/20    202695
# 9/25/20    203610
# 9/26/20    204393
# 9/27/20    204705
# 9/28/20    205046
# 9/29/20    205948
# 9/30/20    206880
# 10/1/20    207796
# 10/2/20    208637
# 10/3/20    209323
# 10/4/20    209692
# dtype: int64
# last date history 10/4/20
# euler-lagrange method input: 9/30/20    206880
# 10/1/20    207796
# 10/2/20    208637
# 10/3/20    209323
# 10/4/20    209692
# dtype: int64
# euler-lagrange derivative209692-205046= 4646
# euler-lagrange 2nd derivative: -48.65310258490342
# number of weeks to future and correction 1 -48.65310258490342
# euler pred with dedicated function 4597.3468974150965
# cdc estimate 4706.0 for 2020-10-10 00:00:00 or 2020-10-10 00:00:00 >>>
# <<<prediction date 10/17/20
# ind element on covid data 281 219658
# current week (prediction week) 10/11/20    214876
# 10/12/20    215274
# 10/13/20    216051
# 10/14/20    217050
# 10/15/20    217895
# 10/16/20    218838
# 10/17/20    219658
# dtype: int64
# current week dead diff 4782
# historical slice 9/28/20     205046
# 9/29/20     205948
# 9/30/20     206880
# 10/1/20     207796
# 10/2/20     208637
# 10/3/20     209323
# 10/4/20     209692
# 10/5/20     210174
# 10/6/20     210875
# 10/7/20     211794
# 10/8/20     212776
# 10/9/20     213749
# 10/10/20    214409
# 10/11/20    214876
# dtype: int64
# last date history 10/11/20
# euler-lagrange method input: 10/7/20     211794
# 10/8/20     212776
# 10/9/20     213749
# 10/10/20    214409
# 10/11/20    214876
# dtype: int64
# euler-lagrange derivative214876-210174= 4702
# euler-lagrange 2nd derivative: -2.051595312469601
# number of weeks to future and correction 1 -2.051595312469601
# euler pred with dedicated function 4699.9484046875305
# cdc estimate 5033.0 for 2020-10-17 00:00:00 or 2020-10-17 00:00:00 >>>
# <<<prediction date 10/24/20
# ind element on covid data 288 225492
# current week (prediction week) 10/18/20    220121
# 10/19/20    220611
# 10/20/20    221548
# 10/21/20    222722
# 10/22/20    223579
# 10/23/20    224529
# 10/24/20    225492
# dtype: int64
# current week dead diff 5371
# historical slice 10/5/20     210174
# 10/6/20     210875
# 10/7/20     211794
# 10/8/20     212776
# 10/9/20     213749
# 10/10/20    214409
# 10/11/20    214876
# 10/12/20    215274
# 10/13/20    216051
# 10/14/20    217050
# 10/15/20    217895
# 10/16/20    218838
# 10/17/20    219658
# 10/18/20    220121
# dtype: int64
# last date history 10/18/20
# euler-lagrange method input: 10/14/20    217050
# 10/15/20    217895
# 10/16/20    218838
# 10/17/20    219658
# 10/18/20    220121
# dtype: int64
# euler-lagrange derivative220121-215274= 4847
# euler-lagrange 2nd derivative: -6.1377383850503975
# number of weeks to future and correction 1 -6.1377383850503975
# euler pred with dedicated function 4840.86226161495
# cdc estimate 5004.0 for 2020-10-24 00:00:00 or 2020-10-24 00:00:00 >>>
# <<<prediction date 10/31/20
# ind element on covid data 295 231515
# current week (prediction week) 10/25/20    225950
# 10/26/20    226472
# 10/27/20    227483
# 10/28/20    228517
# 10/29/20    229520
# 10/30/20    230584
# 10/31/20    231515
# dtype: int64
# current week dead diff 5565
# historical slice 10/12/20    215274
# 10/13/20    216051
# 10/14/20    217050
# 10/15/20    217895
# 10/16/20    218838
# 10/17/20    219658
# 10/18/20    220121
# 10/19/20    220611
# 10/20/20    221548
# 10/21/20    222722
# 10/22/20    223579
# 10/23/20    224529
# 10/24/20    225492
# 10/25/20    225950
# dtype: int64
# last date history 10/25/20
# euler-lagrange method input: 10/21/20    222722
# 10/22/20    223579
# 10/23/20    224529
# 10/24/20    225492
# 10/25/20    225950
# dtype: int64
# euler-lagrange derivative225950-220611= 5339
# euler-lagrange 2nd derivative: -5.024246407078806
# number of weeks to future and correction 1 -5.024246407078806
# euler pred with dedicated function 5333.975753592921
# cdc estimate 5354.0 for 2020-10-31 00:00:00 or 2020-10-31 00:00:00 >>>
# <<<prediction date 11/7/20
# ind element on covid data 302 238788
# current week (prediction week) 11/1/20    232018
# 11/2/20    232575
# 11/3/20    234172
# 11/4/20    235292
# 11/5/20    236457
# 11/6/20    237671
# 11/7/20    238788
# dtype: int64
# current week dead diff 6770
# historical slice 10/19/20    220611
# 10/20/20    221548
# 10/21/20    222722
# 10/22/20    223579
# 10/23/20    224529
# 10/24/20    225492
# 10/25/20    225950
# 10/26/20    226472
# 10/27/20    227483
# 10/28/20    228517
# 10/29/20    229520
# 10/30/20    230584
# 10/31/20    231515
# 11/1/20     232018
# dtype: int64
# last date history 11/1/20
# euler-lagrange method input: 10/28/20    228517
# 10/29/20    229520
# 10/30/20    230584
# 10/31/20    231515
# 11/1/20     232018
# dtype: int64
# euler-lagrange derivative232018-226472= 5546
# euler-lagrange 2nd derivative: -15.350525070703782
# number of weeks to future and correction 1 -15.350525070703782
# euler pred with dedicated function 5530.649474929296
# cdc estimate 6210.0 for 2020-11-07 00:00:00 or 2020-11-07 00:00:00 >>>
# <<<prediction date 11/14/20
# ind element on covid data 309 246746
# current week (prediction week) 11/8/20     239351
# 11/9/20     240110
# 11/10/20    241526
# 11/11/20    242969
# 11/12/20    244173
# 11/13/20    245373
# 11/14/20    246746
# dtype: int64
# current week dead diff 7395
# historical slice 10/26/20    226472
# 10/27/20    227483
# 10/28/20    228517
# 10/29/20    229520
# 10/30/20    230584
# 10/31/20    231515
# 11/1/20     232018
# 11/2/20     232575
# 11/3/20     234172
# 11/4/20     235292
# 11/5/20     236457
# 11/6/20     237671
# 11/7/20     238788
# 11/8/20     239351
# dtype: int64
# last date history 11/8/20
# euler-lagrange method input: 11/4/20    235292
# 11/5/20    236457
# 11/6/20    237671
# 11/7/20    238788
# 11/8/20    239351
# dtype: int64
# euler-lagrange derivative239351-232575= 6776
# euler-lagrange 2nd derivative: 1.4620409134422516
# number of weeks to future and correction 1 1.4620409134422516
# euler pred with dedicated function 6777.462040913442
# cdc estimate 6930.0 for 2020-11-14 00:00:00 or 2020-11-14 00:00:00 >>>
# <<<prediction date 11/21/20
# ind element on covid data 316 257628
# current week (prediction week) 11/15/20    247534
# 11/16/20    248348
# 11/17/20    250057
# 11/18/20    251999
# 11/19/20    254041
# 11/20/20    255990
# 11/21/20    257628
# dtype: int64
# current week dead diff 10094
# historical slice 11/2/20     232575
# 11/3/20     234172
# 11/4/20     235292
# 11/5/20     236457
# 11/6/20     237671
# 11/7/20     238788
# 11/8/20     239351
# 11/9/20     240110
# 11/10/20    241526
# 11/11/20    242969
# 11/12/20    244173
# 11/13/20    245373
# 11/14/20    246746
# 11/15/20    247534
# dtype: int64
# last date history 11/15/20
# euler-lagrange method input: 11/11/20    242969
# 11/12/20    244173
# 11/13/20    245373
# 11/14/20    246746
# 11/15/20    247534
# dtype: int64
# euler-lagrange derivative247534-240110= 7424
# euler-lagrange 2nd derivative: 12.374237352914179
# number of weeks to future and correction 1 12.374237352914179
# euler pred with dedicated function 7436.374237352914
# cdc estimate 8285.0 for 2020-11-21 00:00:00 or 2020-11-21 00:00:00 >>>
# <<<prediction date 11/28/20
# ind element on covid data 323 268464
# current week (prediction week) 11/22/20    258689
# 11/23/20    259762
# 11/24/20    261898
# 11/25/20    264151
# 11/26/20    265554
# 11/27/20    267106
# 11/28/20    268464
# dtype: int64
# current week dead diff 9775
# historical slice 11/9/20     240110
# 11/10/20    241526
# 11/11/20    242969
# 11/12/20    244173
# 11/13/20    245373
# 11/14/20    246746
# 11/15/20    247534
# 11/16/20    248348
# 11/17/20    250057
# 11/18/20    251999
# 11/19/20    254041
# 11/20/20    255990
# 11/21/20    257628
# 11/22/20    258689
# dtype: int64
# last date history 11/22/20
# euler-lagrange method input: 11/18/20    251999
# 11/19/20    254041
# 11/20/20    255990
# 11/21/20    257628
# 11/22/20    258689
# dtype: int64
# euler-lagrange derivative258689-248348= 10341
# euler-lagrange 2nd derivative: 127.36263595308924
# number of weeks to future and correction 1 127.36263595308924
# euler pred with dedicated function 10468.36263595309
# cdc estimate 13778.0 for 2020-11-28 00:00:00 or 2020-11-28 00:00:00 >>>
# <<<prediction date 12/5/20
# ind element on covid data 330 284180
# current week (prediction week) 11/29/20    269515
# 11/30/20    270827
# 12/1/20     273379
# 12/2/20     276209
# 12/3/20     279178
# 12/4/20     281790
# 12/5/20     284180
# dtype: int64
# current week dead diff 14665
# historical slice 11/16/20    248348
# 11/17/20    250057
# 11/18/20    251999
# 11/19/20    254041
# 11/20/20    255990
# 11/21/20    257628
# 11/22/20    258689
# 11/23/20    259762
# 11/24/20    261898
# 11/25/20    264151
# 11/26/20    265554
# 11/27/20    267106
# 11/28/20    268464
# 11/29/20    269515
# dtype: int64
# last date history 11/29/20
# euler-lagrange method input: 11/25/20    264151
# 11/26/20    265554
# 11/27/20    267106
# 11/28/20    268464
# 11/29/20    269515
# dtype: int64
# euler-lagrange derivative269515-259762= 9753
# euler-lagrange 2nd derivative: -156.33393108929693
# number of weeks to future and correction 1 -156.33393108929693
# euler pred with dedicated function 9596.666068910703
# cdc estimate 10277.0 for 2020-12-05 00:00:00 or 2020-12-05 00:00:00 >>>
# <<<prediction date 12/12/20
# ind element on covid data 337 301806
# current week (prediction week) 12/6/20     285583
# 12/7/20     287142
# 12/8/20     289725
# 12/9/20     292906
# 12/10/20    295892
# 12/11/20    299273
# 12/12/20    301806
# dtype: int64
# current week dead diff 16223
# historical slice 11/23/20    259762
# 11/24/20    261898
# 11/25/20    264151
# 11/26/20    265554
# 11/27/20    267106
# 11/28/20    268464
# 11/29/20    269515
# 11/30/20    270827
# 12/1/20     273379
# 12/2/20     276209
# 12/3/20     279178
# 12/4/20     281790
# 12/5/20     284180
# 12/6/20     285583
# dtype: int64
# last date history 12/6/20
# euler-lagrange method input: 12/2/20    276209
# 12/3/20    279178
# 12/4/20    281790
# 12/5/20    284180
# 12/6/20    285583
# dtype: int64
# euler-lagrange derivative285583-270827= 14756
# euler-lagrange 2nd derivative: 197.79222229852564
# number of weeks to future and correction 1 197.79222229852564
# euler pred with dedicated function 14953.792222298525
# cdc estimate 14899.0 for 2020-12-12 00:00:00 or 2020-12-12 00:00:00 >>>
# <<<prediction date 12/19/20
# ind element on covid data 344 320980
# current week (prediction week) 12/13/20    303465
# 12/14/20    305114
# 12/15/20    308101
# 12/16/20    311834
# 12/17/20    315284
# 12/18/20    318226
# 12/19/20    320980
# dtype: int64
# current week dead diff 17515
# historical slice 11/30/20    270827
# 12/1/20     273379
# 12/2/20     276209
# 12/3/20     279178
# 12/4/20     281790
# 12/5/20     284180
# 12/6/20     285583
# 12/7/20     287142
# 12/8/20     289725
# 12/9/20     292906
# 12/10/20    295892
# 12/11/20    299273
# 12/12/20    301806
# 12/13/20    303465
# dtype: int64
# last date history 12/13/20
# euler-lagrange method input: 12/9/20     292906
# 12/10/20    295892
# 12/11/20    299273
# 12/12/20    301806
# 12/13/20    303465
# dtype: int64
# euler-lagrange derivative303465-287142= 16323
# euler-lagrange 2nd derivative: -2.180967510082496
# number of weeks to future and correction 1 -2.180967510082496
# euler pred with dedicated function 16320.819032489917
# cdc estimate 15495.48 for 2020-12-19 00:00:00 or 2020-12-19 00:00:00 >>>
# <<<prediction date 12/26/20
# ind element on covid data 351 337563
# current week (prediction week) 12/20/20    322749
# 12/21/20    324546
# 12/22/20    327844
# 12/23/20    331223
# 12/24/20    334145
# 12/25/20    335650
# 12/26/20    337563
# dtype: int64
# current week dead diff 14814
# historical slice 12/7/20     287142
# 12/8/20     289725
# 12/9/20     292906
# 12/10/20    295892
# 12/11/20    299273
# 12/12/20    301806
# 12/13/20    303465
# 12/14/20    305114
# 12/15/20    308101
# 12/16/20    311834
# 12/17/20    315284
# 12/18/20    318226
# 12/19/20    320980
# 12/20/20    322749
# dtype: int64
# last date history 12/20/20
# euler-lagrange method input: 12/16/20    311834
# 12/17/20    315284
# 12/18/20    318226
# 12/19/20    320980
# 12/20/20    322749
# dtype: int64
# euler-lagrange derivative322749-305114= 17635
# euler-lagrange 2nd derivative: -39.860028692317655
# number of weeks to future and correction 1 -39.860028692317655
# euler pred with dedicated function 17595.139971307683
# cdc estimate 15447.908000000001 for 2020-12-26 00:00:00 or 2020-12-26 00:00:00 >>>
# <<<prediction date 1/2/21
# ind element on covid data 358 356547
# current week (prediction week) 12/27/20    339001
# 12/28/20    340878
# 12/29/20    344494
# 12/30/20    348427
# 12/31/20    351754
# 1/1/21      353948
# 1/2/21      356547
# dtype: int64
# current week dead diff 17546
# historical slice 12/14/20    305114
# 12/15/20    308101
# 12/16/20    311834
# 12/17/20    315284
# 12/18/20    318226
# 12/19/20    320980
# 12/20/20    322749
# 12/21/20    324546
# 12/22/20    327844
# 12/23/20    331223
# 12/24/20    334145
# 12/25/20    335650
# 12/26/20    337563
# 12/27/20    339001
# dtype: int64
# last date history 12/27/20
# euler-lagrange method input: 12/23/20    331223
# 12/24/20    334145
# 12/25/20    335650
# 12/26/20    337563
# 12/27/20    339001
# dtype: int64
# euler-lagrange derivative339001-324546= 14455
# euler-lagrange 2nd derivative: -348.28053690861907
# number of weeks to future and correction 1 -348.28053690861907
# euler pred with dedicated function 14106.71946309138
# cdc estimate 14044.028 for 2021-01-02 00:00:00 or 2021-01-02 00:00:00 >>>
# <<<prediction date 1/9/21
# ind element on covid data 365 378965
# current week (prediction week) 1/3/21    357984
# 1/4/21    359964
# 1/5/21    363568
# 1/6/21    367492
# 1/7/21    371520
# 1/8/21    375709
# 1/9/21    378965
# dtype: int64
# current week dead diff 20981
# historical slice 12/21/20    324546
# 12/22/20    327844
# 12/23/20    331223
# 12/24/20    334145
# 12/25/20    335650
# 12/26/20    337563
# 12/27/20    339001
# 12/28/20    340878
# 12/29/20    344494
# 12/30/20    348427
# 12/31/20    351754
# 1/1/21      353948
# 1/2/21      356547
# 1/3/21      357984
# dtype: int64
# last date history 1/3/21
# euler-lagrange method input: 12/30/20    348427
# 12/31/20    351754
# 1/1/21      353948
# 1/2/21      356547
# 1/3/21      357984
# dtype: int64
# euler-lagrange derivative357984-340878= 17106
# euler-lagrange 2nd derivative: -49.99235507093283
# number of weeks to future and correction 1 -49.99235507093283
# euler pred with dedicated function 17056.00764492907
# cdc estimate 14744.78 for 2021-01-09 00:00:00 or 2021-01-09 00:00:00 >>>
# <<<prediction date 1/16/21
# ind element on covid data 372 402493
# current week (prediction week) 1/10/21    381069
# 1/11/21    382905
# 1/12/21    387294
# 1/13/21    391312
# 1/14/21    395104
# 1/15/21    398916
# 1/16/21    402493
# dtype: int64
# current week dead diff 21424
# historical slice 12/28/20    340878
# 12/29/20    344494
# 12/30/20    348427
# 12/31/20    351754
# 1/1/21      353948
# 1/2/21      356547
# 1/3/21      357984
# 1/4/21      359964
# 1/5/21      363568
# 1/6/21      367492
# 1/7/21      371520
# 1/8/21      375709
# 1/9/21      378965
# 1/10/21     381069
# dtype: int64
# last date history 1/10/21
# euler-lagrange method input: 1/6/21     367492
# 1/7/21     371520
# 1/8/21     375709
# 1/9/21     378965
# 1/10/21    381069
# dtype: int64
# euler-lagrange derivative381069-359964= 21105
# euler-lagrange 2nd derivative: 126.01052619864322
# number of weeks to future and correction 1 126.01052619864322
# euler pred with dedicated function 21231.010526198643
# cdc estimate 17854.0 for 2021-01-16 00:00:00 or 2021-01-16 00:00:00 >>>
# <<<prediction date 1/23/21
# ind element on covid data 379 424362
# current week (prediction week) 1/17/21    404484
# 1/18/21    406049
# 1/19/21    408450
# 1/20/21    412892
# 1/21/21    417029
# 1/22/21    420806
# 1/23/21    424362
# dtype: int64
# current week dead diff 19878
# historical slice 1/4/21     359964
# 1/5/21     363568
# 1/6/21     367492
# 1/7/21     371520
# 1/8/21     375709
# 1/9/21     378965
# 1/10/21    381069
# 1/11/21    382905
# 1/12/21    387294
# 1/13/21    391312
# 1/14/21    395104
# 1/15/21    398916
# 1/16/21    402493
# 1/17/21    404484
# dtype: int64
# last date history 1/17/21
# euler-lagrange method input: 1/13/21    391312
# 1/14/21    395104
# 1/15/21    398916
# 1/16/21    402493
# 1/17/21    404484
# dtype: int64
# euler-lagrange derivative404484-382905= 21579
# euler-lagrange 2nd derivative: -143.44991104021187
# number of weeks to future and correction 1 -143.44991104021187
# euler pred with dedicated function 21435.55008895979
# cdc estimate 22210.0 for 2021-01-23 00:00:00 or 2021-01-23 00:00:00 >>>
# <<<prediction date 1/30/21
# ind element on covid data 386 446449
# current week (prediction week) 1/24/21    426220
# 1/25/21    427989
# 1/26/21    431971
# 1/27/21    436099
# 1/28/21    439949
# 1/29/21    443548
# 1/30/21    446449
# dtype: int64
# current week dead diff 20229
# historical slice 1/11/21    382905
# 1/12/21    387294
# 1/13/21    391312
# 1/14/21    395104
# 1/15/21    398916
# 1/16/21    402493
# 1/17/21    404484
# 1/18/21    406049
# 1/19/21    408450
# 1/20/21    412892
# 1/21/21    417029
# 1/22/21    420806
# 1/23/21    424362
# 1/24/21    426220
# dtype: int64
# last date history 1/24/21
# euler-lagrange method input: 1/20/21    412892
# 1/21/21    417029
# 1/22/21    420806
# 1/23/21    424362
# 1/24/21    426220
# dtype: int64
# euler-lagrange derivative426220-406049= 20171
# euler-lagrange 2nd derivative: -24.60068299601744
# number of weeks to future and correction 1 -24.60068299601744
# euler pred with dedicated function 20146.399317003983
# cdc estimate 21075.0 for 2021-01-30 00:00:00 or 2021-01-30 00:00:00 >>>
# <<<prediction date 2/6/21
# ind element on covid data 393 467928
# current week (prediction week) 1/31/21    448406
# 2/1/21     450183
# 2/2/21     453716
# 2/3/21     457633
# 2/4/21     461517
# 2/5/21     465191
# 2/6/21     467928
# dtype: int64
# current week dead diff 19522
# historical slice 1/18/21    406049
# 1/19/21    408450
# 1/20/21    412892
# 1/21/21    417029
# 1/22/21    420806
# 1/23/21    424362
# 1/24/21    426220
# 1/25/21    427989
# 1/26/21    431971
# 1/27/21    436099
# 1/28/21    439949
# 1/29/21    443548
# 1/30/21    446449
# 1/31/21    448406
# dtype: int64
# last date history 1/31/21
# euler-lagrange method input: 1/27/21    436099
# 1/28/21    439949
# 1/29/21    443548
# 1/30/21    446449
# 1/31/21    448406
# dtype: int64
# euler-lagrange derivative448406-427989= 20417
# euler-lagrange 2nd derivative: -169.2217591241922
# number of weeks to future and correction 1 -169.2217591241922
# euler pred with dedicated function 20247.778240875807
# cdc estimate 21225.0 for 2021-02-06 00:00:00 or 2021-02-06 00:00:00 >>>
# <<<prediction date 2/13/21
# ind element on covid data 400 485699
# current week (prediction week) 2/7/21     469405
# 2/8/21     470856
# 2/9/21     473921
# 2/10/21    477328
# 2/11/21    480519
# 2/12/21    483403
# 2/13/21    485699
# dtype: int64
# current week dead diff 16294
# historical slice 1/25/21    427989
# 1/26/21    431971
# 1/27/21    436099
# 1/28/21    439949
# 1/29/21    443548
# 1/30/21    446449
# 1/31/21    448406
# 2/1/21     450183
# 2/2/21     453716
# 2/3/21     457633
# 2/4/21     461517
# 2/5/21     465191
# 2/6/21     467928
# 2/7/21     469405
# dtype: int64
# last date history 2/7/21
# euler-lagrange method input: 2/3/21    457633
# 2/4/21    461517
# 2/5/21    465191
# 2/6/21    467928
# 2/7/21    469405
# dtype: int64
# euler-lagrange derivative469405-450183= 19222
# euler-lagrange 2nd derivative: -225.40677839382852
# number of weeks to future and correction 1 -225.40677839382852
# euler pred with dedicated function 18996.59322160617
# cdc estimate 20323.0 for 2021-02-13 00:00:00 or 2021-02-13 00:00:00 >>>
# <<<prediction date 2/20/21
# ind element on covid data 407 499011
# current week (prediction week) 2/14/21    486897
# 2/15/21    487846
# 2/16/21    489490
# 2/17/21    491936
# 2/18/21    494543
# 2/19/21    497078
# 2/20/21    499011
# dtype: int64
# current week dead diff 12114
# historical slice 2/1/21     450183
# 2/2/21     453716
# 2/3/21     457633
# 2/4/21     461517
# 2/5/21     465191
# 2/6/21     467928
# 2/7/21     469405
# 2/8/21     470856
# 2/9/21     473921
# 2/10/21    477328
# 2/11/21    480519
# 2/12/21    483403
# 2/13/21    485699
# 2/14/21    486897
# dtype: int64
# last date history 2/14/21
# euler-lagrange method input: 2/10/21    477328
# 2/11/21    480519
# 2/12/21    483403
# 2/13/21    485699
# 2/14/21    486897
# dtype: int64
# euler-lagrange derivative486897-470856= 16041
# euler-lagrange 2nd derivative: -329.0143176764336
# number of weeks to future and correction 1 -329.0143176764336
# euler pred with dedicated function 15711.985682323566
# cdc estimate 22797.0 for 2021-02-20 00:00:00 or 2021-02-20 00:00:00 >>>
# <<<prediction date 2/27/21
# ind element on covid data 414 513085
# current week (prediction week) 2/21/21    500238
# 2/22/21    501439
# 2/23/21    503715
# 2/24/21    506979
# 2/25/21    509409
# 2/26/21    511564
# 2/27/21    513085
# dtype: int64
# current week dead diff 12847
# historical slice 2/8/21     470856
# 2/9/21     473921
# 2/10/21    477328
# 2/11/21    480519
# 2/12/21    483403
# 2/13/21    485699
# 2/14/21    486897
# 2/15/21    487846
# 2/16/21    489490
# 2/17/21    491936
# 2/18/21    494543
# 2/19/21    497078
# 2/20/21    499011
# 2/21/21    500238
# dtype: int64
# last date history 2/21/21
# euler-lagrange method input: 2/17/21    491936
# 2/18/21    494543
# 2/19/21    497078
# 2/20/21    499011
# 2/21/21    500238
# dtype: int64
# euler-lagrange derivative500238-487846= 12392
# euler-lagrange 2nd derivative: -125.61574602770668
# number of weeks to future and correction 1 -125.61574602770668
# euler pred with dedicated function 12266.384253972294
# cdc estimate 11285.0 for 2021-02-27 00:00:00 or 2021-02-27 00:00:00 >>>
# <<<prediction date 3/6/21
# ind element on covid data 421 525231
# current week (prediction week) 2/28/21    514192
# 3/1/21     515511
# 3/2/21     517444
# 3/3/21     520025
# 3/4/21     521977
# 3/5/21     523700
# 3/6/21     525231
# dtype: int64
# current week dead diff 11039
# historical slice 2/15/21    487846
# 2/16/21    489490
# 2/17/21    491936
# 2/18/21    494543
# 2/19/21    497078
# 2/20/21    499011
# 2/21/21    500238
# 2/22/21    501439
# 2/23/21    503715
# 2/24/21    506979
# 2/25/21    509409
# 2/26/21    511564
# 2/27/21    513085
# 2/28/21    514192
# dtype: int64
# last date history 2/28/21
# euler-lagrange method input: 2/24/21    506979
# 2/25/21    509409
# 2/26/21    511564
# 2/27/21    513085
# 2/28/21    514192
# dtype: int64
# euler-lagrange derivative514192-501439= 12753
# euler-lagrange 2nd derivative: -140.07480075944613
# number of weeks to future and correction 1 -140.07480075944613
# euler pred with dedicated function 12612.925199240553
# cdc estimate 10147.0 for 2021-03-06 00:00:00 or 2021-03-06 00:00:00 >>>
# <<<prediction date 3/13/21
# ind element on covid data 428 534005
# current week (prediction week) 3/7/21     525942
# 3/8/21     526647
# 3/9/21     528431
# 3/10/21    530003
# 3/11/21    531577
# 3/12/21    533008
# 3/13/21    534005
# dtype: int64
# current week dead diff 8063
# historical slice 2/22/21    501439
# 2/23/21    503715
# 2/24/21    506979
# 2/25/21    509409
# 2/26/21    511564
# 2/27/21    513085
# 2/28/21    514192
# 3/1/21     515511
# 3/2/21     517444
# 3/3/21     520025
# 3/4/21     521977
# 3/5/21     523700
# 3/6/21     525231
# 3/7/21     525942
# dtype: int64
# last date history 3/7/21
# euler-lagrange method input: 3/3/21    520025
# 3/4/21    521977
# 3/5/21    523700
# 3/6/21    525231
# 3/7/21    525942
# dtype: int64
# euler-lagrange derivative525942-515511= 10431
# euler-lagrange 2nd derivative: -251.93998945336364
# number of weeks to future and correction 1 -251.93998945336364
# euler pred with dedicated function 10179.060010546636
# cdc estimate 11275.0 for 2021-03-13 00:00:00 or 2021-03-13 00:00:00 >>>
# <<<prediction date 3/20/21
# ind element on covid data 435 541182
# current week (prediction week) 3/14/21    534537
# 3/15/21    535237
# 3/16/21    536498
# 3/17/21    537715
# 3/18/21    539363
# 3/19/21    540409
# 3/20/21    541182
# dtype: int64
# current week dead diff 6645
# historical slice 3/1/21     515511
# 3/2/21     517444
# 3/3/21     520025
# 3/4/21     521977
# 3/5/21     523700
# 3/6/21     525231
# 3/7/21     525942
# 3/8/21     526647
# 3/9/21     528431
# 3/10/21    530003
# 3/11/21    531577
# 3/12/21    533008
# 3/13/21    534005
# 3/14/21    534537
# dtype: int64
# last date history 3/14/21
# euler-lagrange method input: 3/10/21    530003
# 3/11/21    531577
# 3/12/21    533008
# 3/13/21    534005
# 3/14/21    534537
# dtype: int64
# euler-lagrange derivative534537-526647= 7890
# euler-lagrange 2nd derivative: -221.52527032140358
# number of weeks to future and correction 1 -221.52527032140358
# euler pred with dedicated function 7668.474729678596
# cdc estimate 8835.0 for 2021-03-20 00:00:00 or 2021-03-20 00:00:00 >>>
# <<<prediction date 3/27/21
# ind element on covid data 442 548325
# current week (prediction week) 3/21/21    541972
# 3/22/21    542505
# 3/23/21    543450
# 3/24/21    544985
# 3/25/21    546343
# 3/26/21    547511
# 3/27/21    548325
# dtype: int64
# current week dead diff 6353
# historical slice 3/8/21     526647
# 3/9/21     528431
# 3/10/21    530003
# 3/11/21    531577
# 3/12/21    533008
# 3/13/21    534005
# 3/14/21    534537
# 3/15/21    535237
# 3/16/21    536498
# 3/17/21    537715
# 3/18/21    539363
# 3/19/21    540409
# 3/20/21    541182
# 3/21/21    541972
# dtype: int64
# last date history 3/21/21
# euler-lagrange method input: 3/17/21    537715
# 3/18/21    539363
# 3/19/21    540409
# 3/20/21    541182
# 3/21/21    541972
# dtype: int64
# euler-lagrange derivative541972-535237= 6735
# euler-lagrange 2nd derivative: -69.4218355690279
# number of weeks to future and correction 1 -69.4218355690279
# euler pred with dedicated function 6665.578164430972
# cdc estimate 7628.0 for 2021-03-27 00:00:00 or 2021-03-27 00:00:00 >>>
# <<<prediction date 4/3/21
# ind element on covid data 449 554250
# current week (prediction week) 3/28/21    548775
# 3/29/21    549429
# 3/30/21    550354
# 3/31/21    551455
# 4/1/21     552578
# 4/2/21     553479
# 4/3/21     554250
# dtype: int64
# current week dead diff 5475
# historical slice 3/15/21    535237
# 3/16/21    536498
# 3/17/21    537715
# 3/18/21    539363
# 3/19/21    540409
# 3/20/21    541182
# 3/21/21    541972
# 3/22/21    542505
# 3/23/21    543450
# 3/24/21    544985
# 3/25/21    546343
# 3/26/21    547511
# 3/27/21    548325
# 3/28/21    548775
# dtype: int64
# last date history 3/28/21
# euler-lagrange method input: 3/24/21    544985
# 3/25/21    546343
# 3/26/21    547511
# 3/27/21    548325
# 3/28/21    548775
# dtype: int64
# euler-lagrange derivative548775-542505= 6270
# euler-lagrange 2nd derivative: -80.23771177185353
# number of weeks to future and correction 1 -80.23771177185353
# euler pred with dedicated function 6189.762288228147
# cdc estimate 6605.0 for 2021-04-03 00:00:00 or 2021-04-03 00:00:00 >>>
# <<<prediction date 4/10/21
# ind element on covid data 456 561145
# current week (prediction week) 4/4/21     554553
# 4/5/21     555010
# 4/6/21     555874
# 4/7/21     558468
# 4/8/21     559511
# 4/9/21     560421
# 4/10/21    561145
# dtype: int64
# current week dead diff 6592
# historical slice 3/22/21    542505
# 3/23/21    543450
# 3/24/21    544985
# 3/25/21    546343
# 3/26/21    547511
# 3/27/21    548325
# 3/28/21    548775
# 3/29/21    549429
# 3/30/21    550354
# 3/31/21    551455
# 4/1/21     552578
# 4/2/21     553479
# 4/3/21     554250
# 4/4/21     554553
# dtype: int64
# last date history 4/4/21
# euler-lagrange method input: 3/31/21    551455
# 4/1/21     552578
# 4/2/21     553479
# 4/3/21     554250
# 4/4/21     554553
# dtype: int64
# euler-lagrange derivative554553-549429= 5124
# euler-lagrange 2nd derivative: -126.85887950895852
# number of weeks to future and correction 1 -126.85887950895852
# euler pred with dedicated function 4997.141120491042
# cdc estimate 4933.0 for 2021-04-10 00:00:00 or 2021-04-10 00:00:00 >>>
# <<<prediction date 4/17/21
# ind element on covid data 463 566169
# current week (prediction week) 4/11/21    561430
# 4/12/21    561882
# 4/13/21    562759
# 4/14/21    563695
# 4/15/21    564600
# 4/16/21    565461
# 4/17/21    566169
# dtype: int64
# current week dead diff 4739
# historical slice 3/29/21    549429
# 3/30/21    550354
# 3/31/21    551455
# 4/1/21     552578
# 4/2/21     553479
# 4/3/21     554250
# 4/4/21     554553
# 4/5/21     555010
# 4/6/21     555874
# 4/7/21     558468
# 4/8/21     559511
# 4/9/21     560421
# 4/10/21    561145
# 4/11/21    561430
# dtype: int64
# last date history 4/11/21
# euler-lagrange method input: 4/7/21     558468
# 4/8/21     559511
# 4/9/21     560421
# 4/10/21    561145
# 4/11/21    561430
# dtype: int64
# euler-lagrange derivative561430-555010= 6420
# euler-lagrange 2nd derivative: -68.53545350971996
# number of weeks to future and correction 1 -68.53545350971996
# euler pred with dedicated function 6351.46454649028
# cdc estimate 7214.0 for 2021-04-17 00:00:00 or 2021-04-17 00:00:00 >>>
# <<<prediction date 4/24/21
# ind element on covid data 470 571209
# current week (prediction week) 4/18/21    566498
# 4/19/21    567002
# 4/20/21    567849
# 4/21/21    568738
# 4/22/21    569683
# 4/23/21    570445
# 4/24/21    571209
# dtype: int64
# current week dead diff 4711
# historical slice 4/5/21     555010
# 4/6/21     555874
# 4/7/21     558468
# 4/8/21     559511
# 4/9/21     560421
# 4/10/21    561145
# 4/11/21    561430
# 4/12/21    561882
# 4/13/21    562759
# 4/14/21    563695
# 4/15/21    564600
# 4/16/21    565461
# 4/17/21    566169
# 4/18/21    566498
# dtype: int64
# last date history 4/18/21
# euler-lagrange method input: 4/14/21    563695
# 4/15/21    564600
# 4/16/21    565461
# 4/17/21    566169
# 4/18/21    566498
# dtype: int64
# euler-lagrange derivative566498-561882= 4616
# euler-lagrange 2nd derivative: -116.22773484501556
# number of weeks to future and correction 1 -116.22773484501556
# euler pred with dedicated function 4499.772265154985
# cdc estimate 5629.83333333333 for 2021-04-24 00:00:00 or 2021-04-24 00:00:00 >>>
# <<<prediction date 5/1/21
# ind element on covid data 477 576092
# current week (prediction week) 4/25/21    571503
# 4/26/21    571976
# 4/27/21    572652
# 4/28/21    573646
# 4/29/21    574539
# 4/30/21    575347
# 5/1/21     576092
# dtype: int64
# current week dead diff 4589
# historical slice 4/12/21    561882
# 4/13/21    562759
# 4/14/21    563695
# 4/15/21    564600
# 4/16/21    565461
# 4/17/21    566169
# 4/18/21    566498
# 4/19/21    567002
# 4/20/21    567849
# 4/21/21    568738
# 4/22/21    569683
# 4/23/21    570445
# 4/24/21    571209
# 4/25/21    571503
# dtype: int64
# last date history 4/25/21
# euler-lagrange method input: 4/21/21    568738
# 4/22/21    569683
# 4/23/21    570445
# 4/24/21    571209
# 4/25/21    571503
# dtype: int64
# euler-lagrange derivative571503-567002= 4501
# euler-lagrange 2nd derivative: -36.27609355135985
# number of weeks to future and correction 1 -36.27609355135985
# euler pred with dedicated function 4464.72390644864
# cdc estimate 4400.0 for 2021-05-01 00:00:00 or 2021-05-01 00:00:00 >>>
# <<<prediction date 5/8/21
# ind element on covid data 484 580897
# current week (prediction week) 5/2/21    576413
# 5/3/21    576886
# 5/4/21    577798
# 5/5/21    578611
# 5/6/21    579438
# 5/7/21    580262
# 5/8/21    580897
# dtype: int64
# current week dead diff 4484
# historical slice 4/19/21    567002
# 4/20/21    567849
# 4/21/21    568738
# 4/22/21    569683
# 4/23/21    570445
# 4/24/21    571209
# 4/25/21    571503
# 4/26/21    571976
# 4/27/21    572652
# 4/28/21    573646
# 4/29/21    574539
# 4/30/21    575347
# 5/1/21     576092
# 5/2/21     576413
# dtype: int64
# last date history 5/2/21
# euler-lagrange method input: 4/28/21    573646
# 4/29/21    574539
# 4/30/21    575347
# 5/1/21     576092
# 5/2/21     576413
# dtype: int64
# euler-lagrange derivative576413-571976= 4437
# euler-lagrange 2nd derivative: -30.50521379460173
# number of weeks to future and correction 1 -30.50521379460173
# euler pred with dedicated function 4406.494786205399
# cdc estimate 5189.0 for 2021-05-08 00:00:00 or 2021-05-08 00:00:00 >>>
# <<<prediction date 5/15/21
# ind element on covid data 491 584984
# current week (prediction week) 5/9/21     581136
# 5/10/21    581535
# 5/11/21    582235
# 5/12/21    583033
# 5/13/21    583823
# 5/14/21    584455
# 5/15/21    584984
# dtype: int64
# current week dead diff 3848
# historical slice 4/26/21    571976
# 4/27/21    572652
# 4/28/21    573646
# 4/29/21    574539
# 4/30/21    575347
# 5/1/21     576092
# 5/2/21     576413
# 5/3/21     576886
# 5/4/21     577798
# 5/5/21     578611
# 5/6/21     579438
# 5/7/21     580262
# 5/8/21     580897
# 5/9/21     581136
# dtype: int64
# last date history 5/9/21
# euler-lagrange method input: 5/5/21    578611
# 5/6/21    579438
# 5/7/21    580262
# 5/8/21    580897
# 5/9/21    581136
# dtype: int64
# euler-lagrange derivative581136-576886= 4250
# euler-lagrange 2nd derivative: -76.02416730483964
# number of weeks to future and correction 1 -76.02416730483964
# euler pred with dedicated function 4173.9758326951605
# cdc estimate 4829.0 for 2021-05-15 00:00:00 or 2021-05-15 00:00:00 >>>
# <<<prediction date 5/22/21
# ind element on covid data 498 588909
# current week (prediction week) 5/16/21    585248
# 5/17/21    585642
# 5/18/21    586422
# 5/19/21    587106
# 5/20/21    587790
# 5/21/21    588425
# 5/22/21    588909
# dtype: int64
# current week dead diff 3661
# historical slice 5/3/21     576886
# 5/4/21     577798
# 5/5/21     578611
# 5/6/21     579438
# 5/7/21     580262
# 5/8/21     580897
# 5/9/21     581136
# 5/10/21    581535
# 5/11/21    582235
# 5/12/21    583033
# 5/13/21    583823
# 5/14/21    584455
# 5/15/21    584984
# 5/16/21    585248
# dtype: int64
# last date history 5/16/21
# euler-lagrange method input: 5/12/21    583033
# 5/13/21    583823
# 5/14/21    584455
# 5/15/21    584984
# 5/16/21    585248
# dtype: int64
# euler-lagrange derivative585248-581535= 3713
# euler-lagrange 2nd derivative: -64.50195153315028
# number of weeks to future and correction 1 -64.50195153315028
# euler pred with dedicated function 3648.49804846685
# cdc estimate 3462.0 for 2021-05-22 00:00:00 or 2021-05-22 00:00:00 >>>
# <<<prediction date 5/29/21
# ind element on covid data 505 593406
# current week (prediction week) 5/23/21    589099
# 5/24/21    589537
# 5/25/21    590184
# 5/26/21    591161
# 5/27/21    592516
# 5/28/21    593056
# 5/29/21    593406
# dtype: int64
# current week dead diff 4307
# historical slice 5/10/21    581535
# 5/11/21    582235
# 5/12/21    583033
# 5/13/21    583823
# 5/14/21    584455
# 5/15/21    584984
# 5/16/21    585248
# 5/17/21    585642
# 5/18/21    586422
# 5/19/21    587106
# 5/20/21    587790
# 5/21/21    588425
# 5/22/21    588909
# 5/23/21    589099
# dtype: int64
# last date history 5/23/21
# euler-lagrange method input: 5/19/21    587106
# 5/20/21    587790
# 5/21/21    588425
# 5/22/21    588909
# 5/23/21    589099
# dtype: int64
# euler-lagrange derivative589099-585642= 3457
# euler-lagrange 2nd derivative: -64.66344110287562
# number of weeks to future and correction 1 -64.66344110287562
# euler pred with dedicated function 3392.336558897124
# cdc estimate 3037.0 for 2021-05-29 00:00:00 or 2021-05-29 00:00:00 >>>
# <<<prediction date 6/5/21
# ind element on covid data 512 596667
# current week (prediction week) 5/30/21    593555
# 5/31/21    593717
# 6/1/21     594356
# 6/2/21     594920
# 6/3/21     595559
# 6/4/21     596086
# 6/5/21     596667
# dtype: int64
# current week dead diff 3112
# historical slice 5/17/21    585642
# 5/18/21    586422
# 5/19/21    587106
# 5/20/21    587790
# 5/21/21    588425
# 5/22/21    588909
# 5/23/21    589099
# 5/24/21    589537
# 5/25/21    590184
# 5/26/21    591161
# 5/27/21    592516
# 5/28/21    593056
# 5/29/21    593406
# 5/30/21    593555
# dtype: int64
# last date history 5/30/21
# euler-lagrange method input: 5/26/21    591161
# 5/27/21    592516
# 5/28/21    593056
# 5/29/21    593406
# 5/30/21    593555
# dtype: int64
# euler-lagrange derivative593555-589537= 4018
# euler-lagrange 2nd derivative: -60.82567567342852
# number of weeks to future and correction 1 -60.82567567342852
# euler pred with dedicated function 3957.1743243265714
# cdc estimate 3945.0 for 2021-06-05 00:00:00 or 2021-06-05 00:00:00 >>>
# <<<prediction date 6/12/21
# ind element on covid data 519 599181
# current week (prediction week) 6/6/21     596831
# 6/7/21     597137
# 6/8/21     597468
# 6/9/21     597948
# 6/10/21    598366
# 6/11/21    598905
# 6/12/21    599181
# dtype: int64
# current week dead diff 2350
# historical slice 5/24/21    589537
# 5/25/21    590184
# 5/26/21    591161
# 5/27/21    592516
# 5/28/21    593056
# 5/29/21    593406
# 5/30/21    593555
# 5/31/21    593717
# 6/1/21     594356
# 6/2/21     594920
# 6/3/21     595559
# 6/4/21     596086
# 6/5/21     596667
# 6/6/21     596831
# dtype: int64
# last date history 6/6/21
# euler-lagrange method input: 6/2/21    594920
# 6/3/21    595559
# 6/4/21    596086
# 6/5/21    596667
# 6/6/21    596831
# dtype: int64
# euler-lagrange derivative596831-593717= 3114
# euler-lagrange 2nd derivative: -59.02253288455819
# number of weeks to future and correction 1 -59.02253288455819
# euler pred with dedicated function 3054.977467115442
# cdc estimate 2568.0 for 2021-06-12 00:00:00 or 2021-06-12 00:00:00 >>>
# <<<prediction date 6/19/21
# ind element on covid data 526 601292
# current week (prediction week) 6/13/21    599285
# 6/14/21    599465
# 6/15/21    599799
# 6/16/21    600182
# 6/17/21    600499
# 6/18/21    601113
# 6/19/21    601292
# dtype: int64
# current week dead diff 2007
# historical slice 5/31/21    593717
# 6/1/21     594356
# 6/2/21     594920
# 6/3/21     595559
# 6/4/21     596086
# 6/5/21     596667
# 6/6/21     596831
# 6/7/21     597137
# 6/8/21     597468
# 6/9/21     597948
# 6/10/21    598366
# 6/11/21    598905
# 6/12/21    599181
# 6/13/21    599285
# dtype: int64
# last date history 6/13/21
# euler-lagrange method input: 6/9/21     597948
# 6/10/21    598366
# 6/11/21    598905
# 6/12/21    599181
# 6/13/21    599285
# dtype: int64
# euler-lagrange derivative599285-597137= 2148
# euler-lagrange 2nd derivative: -65.89403589866942
# number of weeks to future and correction 1 -65.89403589866942
# euler pred with dedicated function 2082.1059641013308
# cdc estimate 2372.0 for 2021-06-19 00:00:00 or 2021-06-19 00:00:00 >>>
# <<<prediction date 6/26/21
# ind element on covid data 533 603396
# current week (prediction week) 6/20/21    601365
# 6/21/21    601623
# 6/22/21    601974
# 6/23/21    602373
# 6/24/21    602713
# 6/25/21    603236
# 6/26/21    603396
# dtype: int64
# current week dead diff 2031
# historical slice 6/7/21     597137
# 6/8/21     597468
# 6/9/21     597948
# 6/10/21    598366
# 6/11/21    598905
# 6/12/21    599181
# 6/13/21    599285
# 6/14/21    599465
# 6/15/21    599799
# 6/16/21    600182
# 6/17/21    600499
# 6/18/21    601113
# 6/19/21    601292
# 6/20/21    601365
# dtype: int64
# last date history 6/20/21
# euler-lagrange method input: 6/16/21    600182
# 6/17/21    600499
# 6/18/21    601113
# 6/19/21    601292
# 6/20/21    601365
# dtype: int64
# euler-lagrange derivative601365-599465= 1900
# euler-lagrange 2nd derivative: -28.38556975809921
# number of weeks to future and correction 1 -28.38556975809921
# euler pred with dedicated function 1871.614430241901
# cdc estimate 1710.0 for 2021-06-26 00:00:00 or 2021-06-26 00:00:00 >>>
# <<<prediction date 7/3/21
# ind element on covid data 540 605058
# current week (prediction week) 6/27/21    603469
# 6/28/21    603615
# 6/29/21    603952
# 6/30/21    604247
# 7/1/21     604533
# 7/2/21     604968
# 7/3/21     605058
# dtype: int64
# current week dead diff 1589
# historical slice 6/14/21    599465
# 6/15/21    599799
# 6/16/21    600182
# 6/17/21    600499
# 6/18/21    601113
# 6/19/21    601292
# 6/20/21    601365
# 6/21/21    601623
# 6/22/21    601974
# 6/23/21    602373
# 6/24/21    602713
# 6/25/21    603236
# 6/26/21    603396
# 6/27/21    603469
# dtype: int64
# last date history 6/27/21
# euler-lagrange method input: 6/23/21    602373
# 6/24/21    602713
# 6/25/21    603236
# 6/26/21    603396
# 6/27/21    603469
# dtype: int64
# euler-lagrange derivative603469-601623= 1846
# euler-lagrange 2nd derivative: -39.386152618421335
# number of weeks to future and correction 1 -39.386152618421335
# euler pred with dedicated function 1806.6138473815786
# cdc estimate 1718.0 for 2021-07-03 00:00:00 or 2021-07-03 00:00:00 >>>
# <<<prediction date 7/10/21
# ind element on covid data 547 606640
# current week (prediction week) 7/4/21     605099
# 7/5/21     605223
# 7/6/21     605523
# 7/7/21     605844
# 7/8/21     606092
# 7/9/21     606554
# 7/10/21    606640
# dtype: int64
# current week dead diff 1541
# historical slice 6/21/21    601623
# 6/22/21    601974
# 6/23/21    602373
# 6/24/21    602713
# 6/25/21    603236
# 6/26/21    603396
# 6/27/21    603469
# ...
# 8/30/21    639430
# 8/31/21    640873
# 9/1/21     642907
# 9/2/21     645860
# 9/3/21     647828
# 9/4/21     648463
# dtype: int64
# current week dead diff 10766
# historical slice 8/16/21    622364
# 8/17/21    623392
# 8/18/21    624567
# 8/19/21    626348
# 8/20/21    627827
# 8/21/21    628379
# 8/22/21    628558
# 8/23/21    629919
# 8/24/21    631341
# 8/25/21    632831
# 8/26/21    635052
# 8/27/21    636775
# 8/28/21    637408
# 8/29/21    637697
# dtype: int64
# last date history 8/29/21
# euler-lagrange method input: 8/25/21    632831
# 8/26/21    635052
# 8/27/21    636775
# 8/28/21    637408
# 8/29/21    637697
# dtype: int64
# euler-lagrange derivative637697-629919= 7778
# euler-lagrange 2nd derivative: -121.22670097929131
# number of weeks to future and correction 1 -121.22670097929131
# euler pred with dedicated function 7656.773299020709
# cdc estimate 10032.0 for 2021-09-04 00:00:00 or 2021-09-04 00:00:00 >>>
# <<<prediction date 9/11/21
# ind element on covid data 610 660321
# current week (prediction week) 9/5/21     648859
# 9/6/21     649458
# 9/7/21     651537
# 9/8/21     653815
# 9/9/21     657099
# 9/10/21    659529
# 9/11/21    660321
# dtype: int64
# current week dead diff 11462
# historical slice 8/23/21    629919
# 8/24/21    631341
# 8/25/21    632831
# 8/26/21    635052
# 8/27/21    636775
# 8/28/21    637408
# 8/29/21    637697
# 8/30/21    639430
# 8/31/21    640873
# 9/1/21     642907
# 9/2/21     645860
# 9/3/21     647828
# 9/4/21     648463
# 9/5/21     648859
# dtype: int64
# last date history 9/5/21
# euler-lagrange method input: 9/1/21    642907
# 9/2/21    645860
# 9/3/21    647828
# 9/4/21    648463
# 9/5/21    648859
# dtype: int64
# euler-lagrange derivative648859-639430= 9429
# euler-lagrange 2nd derivative: -147.27292146792593
# number of weeks to future and correction 1 -147.27292146792593
# euler pred with dedicated function 9281.727078532074
# cdc estimate 11624.0 for 2021-09-11 00:00:00 or 2021-09-11 00:00:00 >>>
# <<<prediction date 9/18/21
# ind element on covid data 617 674376
# current week (prediction week) 9/12/21    660657
# 9/13/21    662812
# 9/14/21    664739
# 9/15/21    667505
# 9/16/21    670966
# 9/17/21    673412
# 9/18/21    674376
# dtype: int64
# current week dead diff 13719
# historical slice 8/30/21    639430
# 8/31/21    640873
# 9/1/21     642907
# 9/2/21     645860
# 9/3/21     647828
# 9/4/21     648463
# 9/5/21     648859
# 9/6/21     649458
# 9/7/21     651537
# 9/8/21     653815
# 9/9/21     657099
# 9/10/21    659529
# 9/11/21    660321
# 9/12/21    660657
# dtype: int64
# last date history 9/12/21
# euler-lagrange method input: 9/8/21     653815
# 9/9/21     657099
# 9/10/21    659529
# 9/11/21    660321
# 9/12/21    660657
# dtype: int64
# euler-lagrange derivative660657-649458= 11199
# euler-lagrange 2nd derivative: -136.1324742996402
# number of weeks to future and correction 1 -136.1324742996402
# euler pred with dedicated function 11062.86752570036
# cdc estimate 12628.0 for 2021-09-18 00:00:00 or 2021-09-18 00:00:00 >>>
# <<<prediction date 9/25/21
# ind element on covid data 624 688749
# current week (prediction week) 9/19/21    674723
# 9/20/21    677008
# 9/21/21    679363
# 9/22/21    682208
# 9/23/21    685475
# 9/24/21    687959
# 9/25/21    688749
# dtype: int64
# current week dead diff 14026
# historical slice 9/6/21     649458
# 9/7/21     651537
# 9/8/21     653815
# 9/9/21     657099
# 9/10/21    659529
# 9/11/21    660321
# 9/12/21    660657
# 9/13/21    662812
# 9/14/21    664739
# 9/15/21    667505
# 9/16/21    670966
# 9/17/21    673412
# 9/18/21    674376
# 9/19/21    674723
# dtype: int64
# last date history 9/19/21
# euler-lagrange method input: 9/15/21    667505
# 9/16/21    670966
# 9/17/21    673412
# 9/18/21    674376
# 9/19/21    674723
# dtype: int64
# euler-lagrange derivative674723-662812= 11911
# euler-lagrange 2nd derivative: -229.20738003132738
# number of weeks to future and correction 1 -229.20738003132738
# euler pred with dedicated function 11681.792619968674
# cdc estimate 13233.0 for 2021-09-25 00:00:00 or 2021-09-25 00:00:00 >>>
# <<<prediction date 10/2/21
# ind element on covid data 631 702500
# current week (prediction week) 9/26/21    689298
# 9/27/21    691602
# 9/28/21    694162
# 9/29/21    696775
# 9/30/21    699572
# 10/1/21    701708
# 10/2/21    702500
# dtype: int64
# current week dead diff 13202
# historical slice 9/13/21    662812
# 9/14/21    664739
# 9/15/21    667505
# 9/16/21    670966
# 9/17/21    673412
# 9/18/21    674376
# 9/19/21    674723
# 9/20/21    677008
# 9/21/21    679363
# 9/22/21    682208
# 9/23/21    685475
# 9/24/21    687959
# 9/25/21    688749
# 9/26/21    689298
# dtype: int64
# last date history 9/26/21
# euler-lagrange method input: 9/22/21    682208
# 9/23/21    685475
# 9/24/21    687959
# 9/25/21    688749
# 9/26/21    689298
# dtype: int64
# euler-lagrange derivative689298-677008= 12290
# euler-lagrange 2nd derivative: -299.8863827373748
# number of weeks to future and correction 1 -299.8863827373748
# euler pred with dedicated function 11990.113617262625
# cdc estimate 10846.0 for 2021-10-02 00:00:00 or 2021-10-02 00:00:00 >>>
# <<<prediction date 10/9/21
# ind element on covid data 638 714229
# current week (prediction week) 10/3/21    702999
# 10/4/21    704958
# 10/5/21    706865
# 10/6/21    709495
# 10/7/21    711973
# 10/8/21    713807
# 10/9/21    714229
# dtype: int64
# current week dead diff 11230
# historical slice 9/20/21    677008
# 9/21/21    679363
# 9/22/21    682208
# 9/23/21    685475
# 9/24/21    687959
# 9/25/21    688749
# 9/26/21    689298
# 9/27/21    691602
# 9/28/21    694162
# 9/29/21    696775
# 9/30/21    699572
# 10/1/21    701708
# 10/2/21    702500
# 10/3/21    702999
# dtype: int64
# last date history 10/3/21
# euler-lagrange method input: 9/29/21    696775
# 9/30/21    699572
# 10/1/21    701708
# 10/2/21    702500
# 10/3/21    702999
# dtype: int64
# euler-lagrange derivative702999-691602= 11397
# euler-lagrange 2nd derivative: -352.33501920980166
# number of weeks to future and correction 1 -352.33501920980166
# euler pred with dedicated function 11044.664980790198
# cdc estimate 11432.0 for 2021-10-09 00:00:00 or 2021-10-09 00:00:00 >>>
# <<<prediction date 10/16/21
# ind element on covid data 645 725869
# current week (prediction week) 10/10/21    714697
# 10/11/21    715800
# 10/12/21    718151
# 10/13/21    721376
# 10/14/21    723517
# 10/15/21    725343
# 10/16/21    725869
# dtype: int64
# current week dead diff 11172
# historical slice 9/27/21     691602
# 9/28/21     694162
# 9/29/21     696775
# 9/30/21     699572
# 10/1/21     701708
# 10/2/21     702500
# 10/3/21     702999
# 10/4/21     704958
# 10/5/21     706865
# 10/6/21     709495
# 10/7/21     711973
# 10/8/21     713807
# 10/9/21     714229
# 10/10/21    714697
# dtype: int64
# last date history 10/10/21
# euler-lagrange method input: 10/6/21     709495
# 10/7/21     711973
# 10/8/21     713807
# 10/9/21     714229
# 10/10/21    714697
# dtype: int64
# euler-lagrange derivative714697-704958= 9739
# euler-lagrange 2nd derivative: -354.0359570542501
# number of weeks to future and correction 1 -354.0359570542501
# euler pred with dedicated function 9384.96404294575
# cdc estimate 10039.0 for 2021-10-16 00:00:00 or 2021-10-16 00:00:00 >>>
# <<<prediction date 10/23/21
# ind element on covid data 652 737825
# current week (prediction week) 10/17/21    726320
# 10/18/21    728064
# 10/19/21    730201
# 10/20/21    733404
# 10/21/21    735392
# 10/22/21    737287
# 10/23/21    737825
# dtype: int64
# current week dead diff 11505
# historical slice 10/4/21     704958
# 10/5/21     706865
# 10/6/21     709495
# 10/7/21     711973
# 10/8/21     713807
# 10/9/21     714229
# 10/10/21    714697
# 10/11/21    715800
# 10/12/21    718151
# 10/13/21    721376
# 10/14/21    723517
# 10/15/21    725343
# 10/16/21    725869
# 10/17/21    726320
# dtype: int64
# last date history 10/17/21
# euler-lagrange method input: 10/13/21    721376
# 10/14/21    723517
# 10/15/21    725343
# 10/16/21    725869
# 10/17/21    726320
# dtype: int64
# euler-lagrange derivative726320-715800= 10520
# euler-lagrange 2nd derivative: -248.68763557769535
# number of weeks to future and correction 1 -248.68763557769535
# euler pred with dedicated function 10271.312364422305
# cdc estimate 9451.0 for 2021-10-23 00:00:00 or 2021-10-23 00:00:00 >>>
# <<<prediction date 10/30/21
# ind element on covid data 659 747110
# current week (prediction week) 10/24/21    738067
# 10/25/21    739480
# 10/26/21    741096
# 10/27/21    743172
# 10/28/21    745014
# 10/29/21    746750
# 10/30/21    747110
# dtype: int64
# current week dead diff 9043
# historical slice 10/11/21    715800
# 10/12/21    718151
# 10/13/21    721376
# 10/14/21    723517
# 10/15/21    725343
# 10/16/21    725869
# 10/17/21    726320
# 10/18/21    728064
# 10/19/21    730201
# 10/20/21    733404
# 10/21/21    735392
# 10/22/21    737287
# 10/23/21    737825
# 10/24/21    738067
# dtype: int64
# last date history 10/24/21
# euler-lagrange method input: 10/20/21    733404
# 10/21/21    735392
# 10/22/21    737287
# 10/23/21    737825
# 10/24/21    738067
# dtype: int64
# euler-lagrange derivative738067-728064= 10003
# euler-lagrange 2nd derivative: -323.6320786502023
# number of weeks to future and correction 1 -323.6320786502023
# euler pred with dedicated function 9679.367921349798
# cdc estimate 9797.0 for 2021-10-30 00:00:00 or 2021-10-30 00:00:00 >>>
# <<<prediction date 11/13/21
# ind element on covid data 673 764090
# current week (prediction week) 11/7/21     755816
# 11/8/21     757029
# 11/9/21     758513
# 11/10/21    760193
# 11/11/21    761048
# 11/12/21    763536
# 11/13/21    764090
# dtype: int64
# current week dead diff 8274
# historical slice 10/25/21    739480
# 10/26/21    741096
# 10/27/21    743172
# 10/28/21    745014
# 10/29/21    746750
# 10/30/21    747110
# 10/31/21    747343
# 11/1/21     748593
# 11/2/21     749877
# 11/3/21     751844
# 11/4/21     753048
# 11/5/21     755171
# 11/6/21     755631
# 11/7/21     755816
# dtype: int64
# last date history 11/7/21
# euler-lagrange method input: 11/3/21    751844
# 11/4/21    753048
# 11/5/21    755171
# 11/6/21    755631
# 11/7/21    755816
# dtype: int64
# euler-lagrange derivative755816-748593= 7223
# euler-lagrange 2nd derivative: -183.48256537510827
# number of weeks to future and correction 1 -183.48256537510827
# euler pred with dedicated function 7039.517434624891
# cdc estimate 8539.0 for 2021-11-13 00:00:00 or 2021-11-13 00:00:00 >>>
# <<<prediction date 11/20/21
# ind element on covid data 680 772116
# current week (prediction week) 11/14/21    764276
# 11/15/21    765544
# 11/16/21    766879
# 11/17/21    768558
# 11/18/21    769880
# 11/19/21    771682
# 11/20/21    772116
# dtype: int64
# current week dead diff 7840
# historical slice 11/1/21     748593
# 11/2/21     749877
# 11/3/21     751844
# 11/4/21     753048
# 11/5/21     755171
# 11/6/21     755631
# 11/7/21     755816
# 11/8/21     757029
# 11/9/21     758513
# 11/10/21    760193
# 11/11/21    761048
# 11/12/21    763536
# 11/13/21    764090
# 11/14/21    764276
# dtype: int64
# last date history 11/14/21
# euler-lagrange method input: 11/10/21    760193
# 11/11/21    761048
# 11/12/21    763536
# 11/13/21    764090
# 11/14/21    764276
# dtype: int64
# euler-lagrange derivative764276-757029= 7247
# euler-lagrange 2nd derivative: -155.44784681918566
# number of weeks to future and correction 1 -155.44784681918566
# euler pred with dedicated function 7091.5521531808145
# cdc estimate 7919.0 for 2021-11-20 00:00:00 or 2021-11-20 00:00:00 >>>
# <<<prediction date 11/27/21
# ind element on covid data 687 777732
# current week (prediction week) 11/21/21    772310
# 11/22/21    773536
# 11/23/21    774896
# 11/24/21    776631
# 11/25/21    777085
# 11/26/21    777440
# 11/27/21    777732
# dtype: int64
# current week dead diff 5422
# historical slice 11/8/21     757029
# 11/9/21     758513
# 11/10/21    760193
# 11/11/21    761048
# 11/12/21    763536
# 11/13/21    764090
# 11/14/21    764276
# 11/15/21    765544
# 11/16/21    766879
# 11/17/21    768558
# 11/18/21    769880
# 11/19/21    771682
# 11/20/21    772116
# 11/21/21    772310
# dtype: int64
# last date history 11/21/21
# euler-lagrange method input: 11/17/21    768558
# 11/18/21    769880
# 11/19/21    771682
# 11/20/21    772116
# 11/21/21    772310
# dtype: int64
# euler-lagrange derivative772310-765544= 6766
# euler-lagrange 2nd derivative: -213.553598953765
# number of weeks to future and correction 1 -213.553598953765
# euler pred with dedicated function 6552.446401046235
# cdc estimate 8514.0 for 2021-11-27 00:00:00 or 2021-11-27 00:00:00 >>>
# <<<prediction date 12/4/21
# ind element on covid data 694 789403
# current week (prediction week) 11/28/21    777933
# 11/29/21    779831
# 11/30/21    781328
# 12/1/21     783329
# 12/2/21     787187
# 12/3/21     788771
# 12/4/21     789403
# dtype: int64
# current week dead diff 11470
# historical slice 11/15/21    765544
# 11/16/21    766879
# 11/17/21    768558
# 11/18/21    769880
# 11/19/21    771682
# 11/20/21    772116
# 11/21/21    772310
# 11/22/21    773536
# 11/23/21    774896
# 11/24/21    776631
# 11/25/21    777085
# 11/26/21    777440
# 11/27/21    777732
# 11/28/21    777933
# dtype: int64
# last date history 11/28/21
# euler-lagrange method input: 11/24/21    776631
# 11/25/21    777085
# 11/26/21    777440
# 11/27/21    777732
# 11/28/21    777933
# dtype: int64
# euler-lagrange derivative777933-773536= 4397
# euler-lagrange 2nd derivative: -340.1170417353922
# number of weeks to future and correction 1 -340.1170417353922
# euler pred with dedicated function 4056.8829582646076
# cdc estimate 6489.0 for 2021-12-04 00:00:00 or 2021-12-04 00:00:00 >>>
# <<<prediction date 12/11/21
# ind element on covid data 701 798063
# current week (prediction week) 12/5/21     789676
# 12/6/21     790961
# 12/7/21     792601
# 12/8/21     794347
# 12/9/21     795794
# 12/10/21    797566
# 12/11/21    798063
# dtype: int64
# current week dead diff 8387
# historical slice 11/22/21    773536
# 11/23/21    774896
# 11/24/21    776631
# 11/25/21    777085
# 11/26/21    777440
# 11/27/21    777732
# 11/28/21    777933
# 11/29/21    779831
# 11/30/21    781328
# 12/1/21     783329
# 12/2/21     787187
# 12/3/21     788771
# 12/4/21     789403
# 12/5/21     789676
# dtype: int64
# last date history 12/5/21
# euler-lagrange method input: 12/1/21    783329
# 12/2/21    787187
# 12/3/21    788771
# 12/4/21    789403
# 12/5/21    789676
# dtype: int64
# euler-lagrange derivative789676-779831= 9845
# euler-lagrange 2nd derivative: 18.359989057546045
# number of weeks to future and correction 1 18.359989057546045
# euler pred with dedicated function 9863.359989057546
# cdc estimate 9659.0 for 2021-12-11 00:00:00 or 2021-12-11 00:00:00 >>>
# <<<prediction date 12/18/21
# ind element on covid data 708 806583
# current week (prediction week) 12/12/21    798299
# 12/13/21    799592
# 12/14/21    801012
# 12/15/21    803189
# 12/16/21    804335
# 12/17/21    806072
# 12/18/21    806583
# dtype: int64
# current week dead diff 8284
# historical slice 11/29/21    779831
# 11/30/21    781328
# 12/1/21     783329
# 12/2/21     787187
# 12/3/21     788771
# 12/4/21     789403
# 12/5/21     789676
# 12/6/21     790961
# 12/7/21     792601
# 12/8/21     794347
# 12/9/21     795794
# 12/10/21    797566
# 12/11/21    798063
# 12/12/21    798299
# dtype: int64
# last date history 12/12/21
# euler-lagrange method input: 12/8/21     794347
# 12/9/21     795794
# 12/10/21    797566
# 12/11/21    798063
# 12/12/21    798299
# dtype: int64
# euler-lagrange derivative798299-790961= 7338
# euler-lagrange 2nd derivative: -320.08905118688875
# number of weeks to future and correction 1 -320.08905118688875
# euler pred with dedicated function 7017.910948813112
# cdc estimate 10276.0 for 2021-12-18 00:00:00 or 2021-12-18 00:00:00 >>>
# <<<prediction date 12/25/21
# ind element on covid data 715 816533
# current week (prediction week) 12/19/21    806749
# 12/20/21    808201
# 12/21/21    810045
# 12/22/21    812069
# 12/23/21    815423
# 12/24/21    816436
# 12/25/21    816533
# dtype: int64
# current week dead diff 9784
# historical slice 12/6/21     790961
# 12/7/21     792601
# 12/8/21     794347
# 12/9/21     795794
# 12/10/21    797566
# 12/11/21    798063
# 12/12/21    798299
# 12/13/21    799592
# 12/14/21    801012
# 12/15/21    803189
# 12/16/21    804335
# 12/17/21    806072
# 12/18/21    806583
# 12/19/21    806749
# dtype: int64
# last date history 12/19/21
# euler-lagrange method input: 12/15/21    803189
# 12/16/21    804335
# 12/17/21    806072
# 12/18/21    806583
# 12/19/21    806749
# dtype: int64
# euler-lagrange derivative806749-799592= 7157
# euler-lagrange 2nd derivative: -162.18552233612343
# number of weeks to future and correction 1 -162.18552233612343
# euler pred with dedicated function 6994.8144776638765
# cdc estimate 9888.0 for 2021-12-25 00:00:00 or 2021-12-25 00:00:00 >>>
# <<<prediction date 1/1/22
# (72,)

# %%
print(df.head())
df.to_csv(f'../../results/error_euler_langrange_cdc_week_{week_forecast}.csv')

#datetime.datetime.strptime("6/14/20", "%m/%d/%y")
# Out:
#   error_euler error_cdc_ensemble cum_error_euler cum_error_cdc_ensemble  \
# 0     124.833               1013         124.833                   1013
# 1     236.173               1098         361.006                   2111
# 2     417.263               1179         778.269                   3290
# 3      233.93                215          1012.2                   3505
# 4     408.451                503         1420.65                   4008
#
#   target_prediction_date prediction_made_date euler_prediction_value  \
# 0             2020-08-08           2020-08-02                6656.17
# 1             2020-08-15           2020-08-09                6757.17
# 2             2020-08-22           2020-08-16                6583.26
# 3             2020-08-29           2020-08-23                6126.93
# 4             2020-09-05           2020-08-30                5845.45
#
#   cdc_prediction_value ground_truth_incidence
# 0                 7794                   6781
# 1                 7619                   6521
# 2                 7345                   6166
# 3                 6108                   5893
# 4                 5940                   5437

# %%
from matplotlib.pyplot import figure

figure(figsize=(16, 10), dpi=400)

plt.plot(df["target_prediction_date"], df["error_cdc_ensemble"])
plt.plot(df["target_prediction_date"], df["error_euler"])
plt.legend(['cdc ensemble error','euler error'])
plt.grid()
plt.savefig(f'../../results/Jan_2022/prediction_error_euler_langrange_week_{week_forecast}.pdf', dpi = 600)
# Out:
# /Users/anino/anaconda3/envs/network_env/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/anino/anaconda3/envs/network_env/lib/python3.6/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/anino/anaconda3/envs/network_env/lib/python3.6/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
df["error_cdc_ensemble"].sort_values()
# Out:
# 9          11
# 49         31
# 52         40
# 48         61
# 8          76
#        ...
# 27       4029
# 17       4388
# 68       4981
# 22    6236.22
# 28      10683
# Name: error_cdc_ensemble, Length: 72, dtype: object

# %%
df["target_prediction_date"][29]
# Out:
# Timestamp('2021-02-27 00:00:00')

# %%
from matplotlib.pyplot import figure

figure(figsize=(16, 10), dpi=400)

plt.plot(df["target_prediction_date"], df["cdc_prediction_value"])
plt.plot(df["target_prediction_date"], df["euler_prediction_value"])
plt.plot(df["target_prediction_date"], df["ground_truth_incidence"])
plt.legend(['cdc ensemble prediction','euler prediction', 'ground truth'])
plt.grid()
plt.savefig(f'../../results/Jan_2022/predictions_euler_langrange_week_{week_forecast}.pdf', dpi = 600)

# %%
figure(figsize=(16, 10), dpi=400)

plt.plot(df["target_prediction_date"], df["cum_error_cdc_ensemble"])
plt.plot(df["target_prediction_date"], df["cum_error_euler"])
plt.grid()

plt.legend(['cumulative cdc ensemble error','cumulative euler error'])

plt.savefig(f'../../results/cumulative_prediction_error_euler_langrange_week_{week_forecast}.png', dpi = 600)

# %%
print("cum cdc error: ", df["cum_error_cdc_ensemble"].iloc[-1])
print("cum euler error: ",  df["cum_error_euler"].iloc[-1])
# Out:
# cum cdc error:  100173.45333333332
# cum euler error:  89392.15693920637
